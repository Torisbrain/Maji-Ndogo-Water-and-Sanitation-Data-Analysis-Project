# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:Robinpass123@localhost:3306/united_nations

# %%
# %%sql
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None)]

# %%
# %%sql
#
# SELECT
#     geo.Country_name,
#     geo.Region,
#     econ.Time_period,
#     econ.Est_gdp_in_billions
# FROM
#     Geographic_Location AS geo
# LEFT JOIN
#     Economic_Indicators AS econ ON geo.Country_name = econ.Country_name
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 'Central and Southern Asia', None, None),
#  ('Algeria', 'Northern Africa and Western Asia', None, None),
#  ('American Samoa', 'Oceania', None, None),
#  ('Angola', 'Sub-Saharan Africa', None, None),
#  ('Anguilla', 'Latin America and the Caribbean', None, None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', None, None),
#  ('Argentina', 'Latin America and the Caribbean', None, None),
#  ('Armenia', 'Northern Africa and Western Asia', None, None),
#  ('Aruba', 'Latin America and the Caribbean', None, None),
#  ('Australia', 'Oceania', None, None)]

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), None, None, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, None, None, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), None, None, None, None, None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), None, None, None, None, None),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), None, None, None, None, None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), None, None, None, None, None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7692020.00'), None, None, None, None, None),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82670.00'), None, None, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, None, None, None, None, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('785.00'), None, None, None, None, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), None, None, None, None, None),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), None, None, None, None, None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), None, None, None, None, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), None, None, None, None, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), None, None, None, None, None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38144.00'), None, None, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, None, None, None, None, None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00'), None, None, None, None, None),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00'), None, None, None, None, None),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00'), None, None, None, None, None),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00'), None, None, None, None, None),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00'), None, None, None, None, None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00'), None, None, None, None, None),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00'), None, None, None, None, None),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00'), None, None, None, None, None),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00'), None, None, None, None, None),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00'), None, None, None, None, None),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('240.00'), None, None, None, None, None),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00'), None, None, None, None, None),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00'), None, None, None, None, None),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00'), None, None, None, None, None),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424702.90'), None, None, None, None, None),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00'), None, None, None, None, None),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00'), None, None, None, None, None),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None, None, None, None, None, None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None, None, None, None, None, None),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00'), None, None, None, None, None),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None, None, None, None, None, None),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('104100.00'), None, None, None, None, None),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None, None, None, None, None, None),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00'), None, None, None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None, None, None, None, None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None, None, None, None, None, None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00'), None, None, None, None, None),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.00'), None, None, None, None, None),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00'), None, None, None, None, None),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00'), None, None, None, None, None)]

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2018, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2019, Decimal('93.33'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, 'Algeria', 2020, Decimal('93.33'), Decimal('84.33')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2015, Decimal('100.00'), Decimal('57.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2016, Decimal('100.00'), Decimal('56.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2017, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2018, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2019, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, 'American Samoa', 2020, Decimal('100.00'), Decimal('54.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), None, None, None, None, None, 'Angola', 2015, Decimal('50.33'), Decimal('43.33')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), None, None, None, None, None, 'Angola', 2016, Decimal('51.00'), Decimal('44.67'))]

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# 	AND econ.Time_period = svc.Time_period
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), None, None, None, None, None, None, None, None, None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), None, None, None, None, None, None, None, None, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), None, None, None, None, None, None, None, None, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), None, None, None, None, None, None, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, None, None, None, None, None, None, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), None, None, None, None, None, None, None, None, None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), None, None, None, None, None, None, None, None, None),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), None, None, None, None, None, None, None, None, None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), None, None, None, None, None, None, None, None, None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7692020.00'), None, None, None, None, None, None, None, None, None),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82670.00'), None, None, None, None, None, None, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, None, None, None, None, None, None, None, None, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('785.00'), None, None, None, None, None, None, None, None, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), None, None, None, None, None, None, None, None, None),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), None, None, None, None, None, None, None, None, None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), None, None, None, None, None, None, None, None, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), None, None, None, None, None, None, None, None, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), None, None, None, None, None, None, None, None, None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38144.00'), None, None, None, None, None, None, None, None, None),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None, None, None, None, None, None, None, None, None, None)]

# %%
# %%sql
#
# SELECT
#     geo.Country_name,
#     geo.Region,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     econ.Pct_unemployment
# FROM
#     Geographic_Location AS geo
# LEFT JOIN
#     Economic_Indicators AS econ
#     ON geo.Country_name = econ.Country_name
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Central and Southern Asia', None, None, None),
#  ('Algeria', 'Northern Africa and Western Asia', None, None, None),
#  ('American Samoa', 'Oceania', None, None, None),
#  ('Angola', 'Sub-Saharan Africa', None, None, None),
#  ('Anguilla', 'Latin America and the Caribbean', None, None, None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', None, None, None),
#  ('Argentina', 'Latin America and the Caribbean', None, None, None),
#  ('Armenia', 'Northern Africa and Western Asia', None, None, None),
#  ('Aruba', 'Latin America and the Caribbean', None, None, None),
#  ('Australia', 'Oceania', None, None, None),
#  ('Azerbaijan', 'Northern Africa and Western Asia', None, None, None),
#  ('Bahamas', 'Latin America and the Caribbean', None, None, None),
#  ('Bahrain', 'Northern Africa and Western Asia', None, None, None),
#  ('Bangladesh', 'Central and Southern Asia', None, None, None),
#  ('Barbados', 'Latin America and the Caribbean', None, None, None),
#  ('Belize', 'Latin America and the Caribbean', None, None, None),
#  ('Benin', 'Sub-Saharan Africa', None, None, None),
#  ('Bermuda', 'Europe and Northern America', None, None, None),
#  ('Bhutan', 'Central and Southern Asia', None, None, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', None, None, None),
#  ('Botswana', 'Sub-Saharan Africa', None, None, None),
#  ('Brazil', 'Latin America and the Caribbean', None, None, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', None, None, None),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', None, None, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', None, None, None),
#  ('Burundi', 'Sub-Saharan Africa', None, None, None),
#  ('Cabo Verde', 'Sub-Saharan Africa', None, None, None),
#  ('Cambodia', 'Eastern and South-Eastern Asia', None, None, None),
#  ('Cameroon', 'Sub-Saharan Africa', None, None, None),
#  ('Canada', 'Europe and Northern America', None, None, None),
#  ('Cayman Islands', 'Latin America and the Caribbean', None, None, None),
#  ('Central African Republic', 'Sub-Saharan Africa', None, None, None),
#  ('Chad', 'Sub-Saharan Africa', None, None, None),
#  ('Chile', 'Latin America and the Caribbean', None, None, None),
#  ('China', 'Eastern and South-Eastern Asia', None, None, None),
#  ('Colombia', 'Latin America and the Caribbean', None, None, None),
#  ('Comoros', 'Sub-Saharan Africa', None, None, None),
#  ('Congo', 'Sub-Saharan Africa', None, None, None),
#  ('Cook Islands', 'Oceania', None, None, None),
#  ('Costa Rica', 'Latin America and the Caribbean', None, None, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', None, None, None),
#  ('Cuba', 'Latin America and the Caribbean', None, None, None),
#  ('Curaçao', 'Latin America and the Caribbean', None, None, None),
#  ('Cyprus', 'Northern Africa and Western Asia', None, None, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', None, None, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', None, None, None),
#  ('Djibouti', 'Sub-Saharan Africa', None, None, None),
#  ('Dominica', 'Latin America and the Caribbean', None, None, None),
#  ('Dominican Republic', 'Latin America and the Caribbean', None, None, None),
#  ('Ecuador', 'Latin America and the Caribbean', None, None, None)]

# %%
# %%sql
#
# SELECT
# 	loc.Country_name,
# 	eco.Time_period,
# 	eco.Pct_unemployment
# FROM
# 	united_nations.Geographic_Location AS loc
# LEFT JOIN
# 	united_nations.Economic_Indicators AS eco
# 	ON eco.Country_name = loc.Country_name
# WHERE REGION LIKE '%Central and Southern Asia%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 14 rows affected.
# [('Afghanistan', None, None),
#  ('Bangladesh', None, None),
#  ('Bhutan', None, None),
#  ('India', None, None),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Kazakhstan', None, None),
#  ('Kyrgyzstan', None, None),
#  ('Maldives', None, None),
#  ('Nepal', None, None),
#  ('Pakistan', None, None),
#  ('Sri Lanka', None, None),
#  ('Tajikistan', None, None),
#  ('Turkmenistan', None, None),
#  ('Uzbekistan', None, None)]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///chinook.db

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name"
# FROM
#     albums a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall'),
#  (3, 'Restless and Wild', 'Restless and Wild'),
#  (4, 'Let There Be Rock', 'Let There Be Rock'),
#  (152, 'Master Of Puppets', 'Master Of Puppets'),
#  (11, 'Out Of Exile', 'Out Of Exile'),
#  (16, 'Black Sabbath', 'Black Sabbath'),
#  (18, 'Body Count', 'Body Count'),
#  (19, 'Chemical Wedding', 'Chemical Wedding'),
#  (21, 'Prenda Minha', 'Prenda Minha'),
#  (23, 'Minha Historia', 'Minha Historia')]

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name"
# FROM
#     albums AS a
# INNER JOIN
#     tracks AS t ON a.AlbumId = t.AlbumId -- STEP 1: Correctly link albums to their tracks using the key.
# WHERE
#     a.Title = t.Name;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall'),
#  (3, 'Restless and Wild', 'Restless and Wild'),
#  (4, 'Let There Be Rock', 'Let There Be Rock'),
#  (11, 'Out Of Exile', 'Out Of Exile'),
#  (16, 'Black Sabbath', 'Black Sabbath'),
#  (18, 'Body Count', 'Body Count'),
#  (19, 'Chemical Wedding', 'Chemical Wedding'),
#  (21, 'Prenda Minha', 'Prenda Minha'),
#  (23, 'Minha Historia', 'Minha Historia'),
#  (25, 'Da Lama Ao Caos', 'Da Lama Ao Caos'),
#  (38, 'Heart of the Night', 'Heart of the Night'),
#  (40, 'Into The Light', 'Into The Light'),
#  (51, "Up An' Atom", "Up An' Atom"),
#  (60, 'Fireball', 'Fireball'),
#  (65, 'Stormbringer', 'Stormbringer'),
#  (66, 'The Battle Rages On', 'The Battle Rages On'),
#  (68, 'Outbreak', 'Outbreak'),
#  (77, 'The Real Thing', 'The Real Thing'),
#  (78, 'Deixa Entrar', 'Deixa Entrar'),
#  (88, 'Faceless', 'Faceless'),
#  (89, 'American Idiot', 'American Idiot'),
#  (97, 'Brave New World', 'Brave New World'),
#  (98, 'Dance Of Death', 'Dance Of Death'),
#  (99, 'Fear Of The Dark', 'Fear Of The Dark'),
#  (101, 'Killers', 'Killers'),
#  (105, 'No Prayer For The Dying', 'No Prayer For The Dying'),
#  (107, 'Powerslave', 'Powerslave'),
#  (110, 'Seventh Son of a Seventh Son', 'Seventh Son of a Seventh Son'),
#  (116, 'Emergency On Planet Earth', 'Emergency On Planet Earth'),
#  (120, 'Are You Experienced?', 'Are You Experienced?'),
#  (124, 'Cafezinho', 'Cafezinho'),
#  (125, 'Living After Midnight', 'Living After Midnight'),
#  (152, 'Master Of Puppets', 'Master Of Puppets'),
#  (154, 'Ride The Lightning', 'Ride The Lightning'),
#  (155, 'St. Anger', 'St. Anger'),
#  (156, '...And Justice For All', '...And Justice For All'),
#  (157, 'Miles Ahead', 'Miles Ahead'),
#  (159, 'Minas', 'Minas'),
#  (160, 'Ace Of Spades', 'Ace Of Spades'),
#  (175, 'Walking Into Clarksdale', 'Walking Into Clarksdale'),
#  (193, 'Blood Sugar Sex Magik', 'Blood Sugar Sex Magik'),
#  (194, 'By The Way', 'By The Way'),
#  (195, 'Californication', 'Californication'),
#  (199, 'Maquinarama', 'Maquinarama'),
#  (204, 'Morning Dance', 'Morning Dance'),
#  (220, 'Transmission', 'Transmission'),
#  (226, 'Battlestar Galactica: The Story So Far', 'Battlestar Galactica: The Story So Far'),
#  (240, 'Zooropa', 'Zooropa'),
#  (271, 'Revelations', 'Revelations'),
#  (321, 'Back to Black', 'Back to Black')]

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name",
#     ar.Name AS "Artist Name"
# FROM
#     albums AS a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# INNER JOIN
#     artists AS ar
#     ON ar.ArtistId = a.ArtistId
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 'Balls to the Wall', 'Accept'),
#  (3, 'Restless and Wild', 'Restless and Wild', 'Accept'),
#  (4, 'Let There Be Rock', 'Let There Be Rock', 'AC/DC'),
#  (11, 'Out Of Exile', 'Out Of Exile', 'Audioslave'),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath'),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath'),
#  (18, 'Body Count', 'Body Count', 'Body Count'),
#  (19, 'Chemical Wedding', 'Chemical Wedding', 'Bruce Dickinson'),
#  (21, 'Prenda Minha', 'Prenda Minha', 'Caetano Veloso'),
#  (23, 'Minha Historia', 'Minha Historia', 'Chico Buarque')]

# %%
# %%sql
#
# SELECT t.AlbumId, t.Name, "Artist" AS "Category"
# FROM tracks AS t
#
# UNION
#
# SELECT a.AlbumId, a.Title, "Album" AS "Category"
# FROM albums AS a
#
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(1, 'Breaking The Rules', 'Artist'),
#  (1, 'C.O.D.', 'Artist'),
#  (1, 'Evil Walks', 'Artist'),
#  (1, 'For Those About To Rock (We Salute You)', 'Artist'),
#  (1, 'For Those About To Rock We Salute You', 'Album'),
#  (1, 'Inject The Venom', 'Artist'),
#  (1, "Let's Get It Up", 'Artist'),
#  (1, 'Night Of The Long Knives', 'Artist'),
#  (1, 'Put The Finger On You', 'Artist'),
#  (1, 'Snowballed', 'Artist')]

# %%
# %%sql
#
# SELECT
#     Name AS "ItemName",
#     'Track' AS "ItemType"
# FROM
#     tracks
#
# UNION
#
# SELECT
#     Title AS "ItemName",
#     'Album' AS "ItemType"
# FROM
#     albums;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('"40"', 'Track'),
#  ('"?"', 'Track'),
#  ('"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro', 'Track'),
#  ('#1 Zero', 'Track'),
#  ('#9 Dream', 'Track'),
#  ("'Round Midnight", 'Track'),
#  ('(Anesthesia) Pulling Teeth', 'Track'),
#  ('(Da Le) Yaleo', 'Track'),
#  ("(I Can't Help) Falling In Love With You", 'Track'),
#  ('(Oh) Pretty Woman', 'Track'),
#  ('(There Is) No Greater Love (Teo Licks)', 'Track'),
#  ('(We Are) The Road Crew', 'Track'),
#  ('(White Man) In Hammersmith Palais', 'Track'),
#  ('(Wish I Could) Hideaway', 'Track'),
#  ('...And Found', 'Track'),
#  ('...And Justice For All', 'Album'),
#  ('...And Justice For All', 'Track'),
#  ('...In Translation', 'Track'),
#  ('.07%', 'Track'),
#  ('01 - Prowler', 'Track'),
#  ('02 - Sanctuary', 'Track'),
#  ('03 - Remember Tomorrow', 'Track'),
#  ('04 - Running Free', 'Track'),
#  ('05 - Phantom of the Opera', 'Track'),
#  ('06 - Transylvania', 'Track'),
#  ('07 - Strange World', 'Track'),
#  ('08 - Charlotte the Harlot', 'Track'),
#  ('09 - Iron Maiden', 'Track'),
#  ('1/2 Full', 'Track'),
#  ('100% HardCore', 'Track'),
#  ('13 Years Of Grief', 'Track'),
#  ('14 Years', 'Track'),
#  ('16 Toneladas', 'Track'),
#  ('1979', 'Track'),
#  ('19th Nervous Breakdown', 'Track'),
#  ('1° De Julho', 'Track'),
#  ('1º De Julho', 'Track'),
#  ('2 A.M.', 'Track'),
#  ('2 Minutes To Midnight', 'Track'),
#  ('2 X 4', 'Track'),
#  ('2,000 Man', 'Track'),
#  ('20 Flight Rock', 'Track'),
#  ('200 Years Old', 'Track'),
#  ('20th Century Masters - The Millennium Collection: The Best of Scorpions', 'Album'),
#  ('2112 Overture', 'Track'),
#  ('22 Acacia Avenue', 'Track'),
#  ('24 Caprices, Op. 1, No. 24, for Solo Violin, in A Minor', 'Track'),
#  ('3 Gymnopédies: No.1 - Lent Et Grave, No.3 - Lent Et Douloureux', 'Track'),
#  ('32 Dentes', 'Track'),
#  ('5.15', 'Track'),
#  ('51st Anniversary', 'Track'),
#  ('A Banda', 'Track'),
#  ('A Bencao E Outros', 'Track'),
#  ('A Benihana Christmas, Pts. 1 & 2', 'Track'),
#  ('A Carta', 'Track'),
#  ('A Castle Full Of Rascals', 'Track'),
#  ('A Copland Celebration, Vol. I', 'Album'),
#  ('A Cor Do Sol', 'Track'),
#  ('A Cura', 'Track'),
#  ('A Day In the Life', 'Track'),
#  ('A Different Kind Of Blue', 'Track'),
#  ('A E O Z', 'Track'),
#  ('A Estrada', 'Track'),
#  ('A Festa Do Santo Reis', 'Track'),
#  ('A Kind Of Magic', 'Track'),
#  ('A Luz De Tieta', 'Track'),
#  ('A Man And A Woman', 'Track'),
#  ('A Matter of Life and Death', 'Album'),
#  ('A Measure of Salvation', 'Track'),
#  ('A Melhor Forma', 'Track'),
#  ('A Menina Dança', 'Track'),
#  ("A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno", 'Track'),
#  ('A Moça e a Chuva', 'Track'),
#  ('A New Flame', 'Track'),
#  ('A Noite Do Meu Bem', 'Track'),
#  ('A Novidade', 'Track'),
#  ('A Novidade (Live)', 'Track'),
#  ('A Paz', 'Track'),
#  ('A Real Dead One', 'Album'),
#  ('A Real Live One', 'Album'),
#  ('A Room At The Heartbreak Hotel', 'Track'),
#  ('A Rua', 'Track'),
#  ('A Small Victory', 'Track'),
#  ('A Sombra Da Maldade', 'Track'),
#  ('A Soprano Inspired', 'Album'),
#  ('A Statistic', 'Track'),
#  ('A Sua', 'Track'),
#  ('A Tale of Two Cities', 'Track'),
#  ('A Tarde', 'Track'),
#  ('A TempestadeTempestade Ou O Livro Dos Dias', 'Album'),
#  ('A Touch Away', 'Track'),
#  ('A Twist In The Tail', 'Track'),
#  ('A Via Láctea', 'Track'),
#  ('A Volta Da Asa Branca', 'Track'),
#  ('A World Without Heroes', 'Track'),
#  ('A Última Guerra', 'Track'),
#  ('A-Sides', 'Album'),
#  ('A.N.D.R.O.T.A.Z.', 'Track'),
#  ('Abandoned', 'Track'),
#  ('Abraham, Martin And John', 'Track'),
#  ('Abrir A Porta', 'Track'),
#  ('Absolute Zero', 'Track'),
#  ('Acacia Avenue', 'Track'),
#  ('Ace Of Spades', 'Album'),
#  ('Ace Of Spades', 'Track'),
#  ('Acelerou', 'Track'),
#  ('Aces High', 'Track'),
#  ('Achilles Last Stand', 'Track'),
#  ('Achtung Baby', 'Album'),
#  ('Acrobat', 'Track'),
#  ('Act IV, Symphony', 'Track'),
#  ('Action', 'Track'),
#  ('Acústico', 'Album'),
#  ('Acústico MTV', 'Album'),
#  ('Acústico MTV [Live]', 'Album'),
#  ('Adagio for Strings from the String Quartet, Op. 11', 'Track'),
#  ('Adams, John: The Chairman Dances', 'Album'),
#  ('Adeus', 'Track'),
#  ('Adios nonino', 'Track'),
#  ('Admirável Gado Novo', 'Track'),
#  ('Adoled (Ocean)', 'Track'),
#  ('Adorate Deum: Gregorian Chant from the Proper of the Mass', 'Album'),
#  ('Adrift', 'Track'),
#  ('Advance Romance', 'Track'),
#  ('Aeroplane Flies High', 'Track'),
#  ('Afraid', 'Track'),
#  ('Afraid To Shoot Strangers', 'Track'),
#  ('Africa Bamba', 'Track'),
#  ('Afrociberdelia', 'Album'),
#  ('After Midnight', 'Track'),
#  ('Aftermath', 'Track'),
#  ('Again', 'Track'),
#  ('Age Of Innocence', 'Track'),
#  ('Agora Que O Dia Acordou', 'Track'),
#  ('Aguia De Ouro 2001', 'Track'),
#  ("Ain't My Bitch", 'Track'),
#  ("Ain't Talkin' 'Bout Love", 'Track'),
#  ("Ain't Talkin' 'bout Love", 'Track'),
#  ('Ainda Lembro', 'Track'),
#  ('Ainda É Cedo', 'Track'),
#  ('Alabama Song', 'Track'),
#  ('Alagados', 'Track'),
#  ('Alarum', 'Track'),
#  ('Alberta', 'Track'),
#  ('Album Of The Year', 'Album'),
#  ('Alcohol', 'Track'),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 'Album'),
#  ('Alcohol Fueled Brewtality Live! [Disc 2]', 'Album'),
#  ('Alegria, Alegria', 'Track'),
#  ('Alexander the Great', 'Track'),
#  ('Ali', 'Track'),
#  ('Alice', 'Track'),
#  ('Alive', 'Track'),
#  ('All Along The Watchtower', 'Track'),
#  ('All Because Of You', 'Track'),
#  ('All Dead, All Dead', 'Track'),
#  ('All For You', 'Track'),
#  ('All I Really Want', 'Track'),
#  ('All I Want Is You', 'Track'),
#  ('All My Life', 'Track'),
#  ('All My Love', 'Track'),
#  ('All Night Thing', 'Track'),
#  ('All Star', 'Track'),
#  ("All That You Can't Leave Behind", 'Album'),
#  ('All Within My Hands', 'Track'),
#  ('All or None', 'Track'),
#  ('All the Best Cowboys Have Daddy Issues', 'Track'),
#  ('Allegri: Miserere', 'Album'),
#  ('Aloha', 'Track'),
#  ('Always Be All Right', 'Track'),
#  ('Always Forever Now', 'Track'),
#  ('Always On The Run', 'Track'),
#  ('Always With Me, Always With You', 'Track'),
#  ('Alô Alô Marciano', 'Track'),
#  ('Alô, Alô, Marciano', 'Track'),
#  ('Am I Evil?', 'Track'),
#  ('Amanda', 'Track'),
#  ('Amanhã Não Se Sabe', 'Track'),
#  ('Amar É Tudo', 'Track'),
#  ('Amazing', 'Track'),
#  ('American Gothic', 'Track'),
#  ('American Idiot', 'Album'),
#  ('American Idiot', 'Track'),
#  ('American Woman', 'Track'),
#  ('Amor De Muito', 'Track'),
#  ('Amor Demais', 'Track'),
#  ('Amy Amy Amy (Outro)', 'Track'),
#  ('And the Cradle Will Rock...', 'Track'),
#  ('Ando Meio Desligado', 'Track'),
#  ('Aneurysm', 'Track'),
#  ('Angel', 'Track'),
#  ('Angel Dust', 'Album'),
#  ('Angel Of Harlem', 'Track'),
#  ('Angela', 'Track'),
#  ('Animal', 'Track'),
#  ('Another Life', 'Track'),
#  ('Another One Bites The Dust', 'Track'),
#  ('Another Round', 'Track'),
#  ('Antene Se', 'Track'),
#  ('Antes Das Seis', 'Track'),
#  ('Anthem', 'Track'),
#  ('Any Colour You Like', 'Track'),
#  ('Anya', 'Track'),
#  ("Anyone's Daughter", 'Track'),
#  ('Anything Goes', 'Track'),
#  ('Anyway, Anyhow, Anywhere', 'Track'),
#  ('Ao Meu Redor', 'Track'),
#  ('Ao Vivo [IMPORT]', 'Album'),
#  ('Aonde Quer Que Eu Va', 'Track'),
#  ('Aos Leões', 'Track'),
#  ('Apache Rose Peacock', 'Track'),
#  ('Apesar De Você', 'Track'),
#  ('Appetite for Destruction', 'Album'),
#  ('Aprendendo A Jogar', 'Track'),
#  ('Aquaman', 'Album'),
#  ('Aquarela (Toquinho)', 'Track'),
#  ('Aquele Abraço', 'Track'),
#  ('Aquilo', 'Track'),
#  ('Arc', 'Track'),
#  ('Are We The Waiting', 'Track'),
#  ('Are You Experienced?', 'Album'),
#  ('Are You Experienced?', 'Track'),
#  ('Are You Gonna Be My Girl', 'Track'),
#  ('Are You Gonna Go My Way', 'Track'),
#  ('Aria Mit 30 Veränderungen, BWV 988 "Goldberg Variations": Aria', 'Track'),
#  ('Armada: Music from the Courts of England and Spain', 'Album'),
#  ('Armadura', 'Track'),
#  ('Armageddon It', 'Track'),
#  ('Arms Around Your Love', 'Track'),
#  ('Army Ants', 'Track'),
#  ('Army Reserve', 'Track'),
#  ('Around The World', 'Track'),
#  ('Arquivo II', 'Album'),
#  ('Arquivo Os Paralamas Do Sucesso', 'Album'),
#  ('Arrepio', 'Track'),
#  ('As Aparências Enganam', 'Track'),
#  ('As Canções de Eu Tu Eles', 'Album'),
#  ('As Dores do Mundo', 'Track'),
#  ('As Pegadas Do Amor', 'Track'),
#  ('As Profecias', 'Track'),
#  ('As Rosas Não Falam (Beth Carvalho)', 'Track'),
#  ('As Tears Go By', 'Track'),
#  ('As The Years Go by', 'Track'),
#  ('As We Sleep', 'Track'),
#  ('Asa Branca', 'Track'),
#  ('Asas', 'Track'),
#  ('Ashes And Ghosts', 'Track'),
#  ('Ashes To Ashes', 'Track'),
#  ('Assaltaram A Gramática', 'Track'),
#  ('Assim Caminha A Humanidade', 'Track'),
#  ('Assum Preto', 'Track'),
#  ('Astronomy', 'Track'),
#  ('Atomic Punk', 'Track'),
#  ('Atras Da Porta', 'Track'),
#  ('Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', 'Track'),
#  ('Atrás Do Trio Elétrico', 'Track'),
#  ('Atrás da Porta', 'Track'),
#  ('Attitude', 'Track'),
#  ('Até Que Enfim Encontrei Você', 'Track'),
#  ('Audioslave', 'Album'),
#  ('Ava Adore', 'Track'),
#  ('Ave Maria', 'Track'),
#  ('Avisa', 'Track'),
#  ('Aviso Aos Navegantes', 'Track'),
#  ('Axé Bahia 2001', 'Album'),
#  ('Azul', 'Track'),
#  ('Azul Da Cor Do Mar', 'Track'),
#  ('Açai', 'Track'),
#  ('B-Sides 1980-1990', 'Album'),
#  ('B.Y.O.B.', 'Track'),
#  ('BBC Sessions [Disc 1] [Live]', 'Album'),
#  ('BBC Sessions [Disc 2] [Live]', 'Album'),
#  ("Baba O'Riley", 'Track'),
#  ("Babe I'm Gonna Leave You", 'Track'),
#  ('Baby', 'Track'),
#  ('Baby Break It Down', 'Track'),
#  ('Babyface', 'Track'),
#  ('Babylon', 'Track'),
#  ('Bach: Goldberg Variations', 'Album'),
#  ('Bach: Orchestral Suites Nos. 1 - 4', 'Album'),
#  ('Bach: The Brandenburg Concertos', 'Album'),
#  ('Bach: The Cello Suites', 'Album'),
#  ('Bach: Toccata & Fugue in D Minor', 'Album'),
#  ('Bach: Violin Concertos', 'Album'),
#  ('Back Door Man', 'Track'),
#  ('Back from Vacation', 'Track'),
#  ('Back in the Village', 'Track'),
#  ('Back off Bitch', 'Track'),
#  ('Back to Black', 'Album'),
#  ('Back to Black', 'Track'),
#  ('BackBeat Soundtrack', 'Album'),
#  ('Bad', 'Track'),
#  ('Bad Apples', 'Track'),
#  ('Bad Attitude', 'Track'),
#  ('Bad Boy', 'Track'),
#  ('Bad Boy Boogie', 'Track'),
#  ('Bad Moon Rising', 'Track'),
#  ('Bad Obsession', 'Track'),
#  ('Bad Seed', 'Track'),
#  ('Bad, Bad Leroy Brown', 'Track'),
#  ('Badge', 'Track'),
#  ('Baixo Rio', 'Track'),
#  ('Baião Ambiental [Instrumental]', 'Track'),
#  ('Baião Da Penha', 'Track'),
#  ('Balada Da Paula', 'Track'),
#  ('Balada Do Amor Inabalável', 'Track'),
#  ('Balada Do Louco', 'Track'),
#  ('Balanço', 'Track'),
#  ('Ballot or the Bullet', 'Track'),
#  ('Balls to the Wall', 'Album'),
#  ('Balls to the Wall', 'Track'),
#  ("Baltar's Escape", 'Track'),
#  ('Baltimore, DC', 'Track'),
#  ('Band Members Discuss Tracks from "Revelations"', 'Track'),
#  ('Banditismo Por Uma Questa', 'Track'),
#  ('Banho De Lua', 'Track'),
#  ('Bankrobber', 'Track'),
#  ('Bark at the Moon', 'Track'),
#  ('Bark at the Moon (Remastered)', 'Album'),
#  ('Bartok: Violin & Viola Concertos', 'Album'),
#  ('Barulhinho Bom', 'Album'),
#  ('Basket Case', 'Track'),
#  ('Basketball', 'Track'),
#  ('Bass Trap', 'Track'),
#  ('Bastille Day', 'Track'),
#  ('Bat Macumba', 'Track'),
#  ('Batalha Naval', 'Track'),
#  ('Bate Lata', 'Track'),
#  ('Battery', 'Track'),
#  ('Battlestar Galactica (Classic), Season 1', 'Album'),
#  ('Battlestar Galactica, Pt. 1', 'Track'),
#  ('Battlestar Galactica, Pt. 2', 'Track'),
#  ('Battlestar Galactica, Pt. 3', 'Track'),
#  ('Battlestar Galactica, Season 3', 'Album'),
#  ('Battlestar Galactica: The Story So Far', 'Album'),
#  ('Battlestar Galactica: The Story So Far', 'Track'),
#  ('Be Aggressive', 'Track'),
#  ('Be Good Johnny', 'Track'),
#  ('Be Mine', 'Track'),
#  ('Be Quick Or Be Dead', 'Track'),
#  ('Be Yourself', 'Track'),
#  ('Beach Games', 'Track'),
#  ('Beach Sequence', 'Track'),
#  ('Beautiful Boy', 'Track'),
#  ('Beautiful Day', 'Track'),
#  ('Because You Are', 'Track'),
#  ('Been A Son', 'Track'),
#  ('Beethoven Piano Sonatas: Moonlight & Pastorale', 'Album'),
#  ('Beethoven: Symhonies Nos. 5 & 6', 'Album'),
#  ("Beethoven: Symphony No. 6 'Pastoral' Etc.", 'Album'),
#  ('Before You Accuse Me', 'Track'),
#  ('Behind The Wall Of Sleep', 'Track'),
#  ('Beija Eu', 'Track'),
#  ('Beija-Flor', 'Track'),
#  ('Beijo Partido', 'Track'),
#  ('Beijo do Olhar', 'Track'),
#  ('Beira Mar', 'Track'),
#  ('Believe', 'Track'),
#  ('Believe in Love', 'Track'),
#  ('Believer', 'Track'),
#  ('Bell Bottom Blues', 'Track'),
#  ('Belong', 'Track'),
#  ('Bem Devagar', 'Track'),
#  ('Bem Leve', 'Track'),
#  ('Ben Franklin', 'Track'),
#  ('Berimbau', 'Track'),
#  ('Berlim', 'Track'),
#  ('Berlioz: Symphonie Fantastique', 'Album'),
#  ('Best Of You', 'Track'),
#  ('Best Thing', 'Track'),
#  ('Beth', 'Track'),
#  ('Better Halves', 'Track'),
#  ('Better Man', 'Track'),
#  ('Better Than You', 'Track'),
#  ('Beyond Good And Evil', 'Album'),
#  ('Bichos Escrotos (Vinheta)', 'Track'),
#  ('Bicycle Race', 'Track'),
#  ('Big Bad Bill (Is Sweet William Now)', 'Track'),
#  ('Big City Nights', 'Track'),
#  ('Big Machine', 'Track'),
#  ('Big Ones', 'Album'),
#  ('Big Wave', 'Track'),
#  ('Billie Jean', 'Track'),
#  ('Binky The Doormat', 'Track'),
#  ('Biruta', 'Track'),
#  ('Bite The Bullet', 'Track'),
#  ('Bitter Pill', 'Track'),
#  ('Bitter Suite: Brief Encounter / Lost Weekend / Blue Angel', 'Track'),
#  ('Bittersweet Me', 'Track'),
#  ('Bizet: Carmen Highlights', 'Album'),
#  ('Black', 'Track'),
#  ('Black Album', 'Album'),
#  ('Black Capricorn Day', 'Track'),
#  ('Black Country Woman', 'Track'),
#  ('Black Diamond', 'Track'),
#  ('Black Dog', 'Track'),
#  ('Black Hole Sun', 'Track'),
#  ('Black Light Syndrome', 'Track'),
#  ('Black Moon Creeping', 'Track'),
#  ('Black Mountain Side', 'Track'),
#  ('Black Night', 'Track'),
#  ('Black Sabbath', 'Album'),
#  ('Black Sabbath', 'Track'),
#  ('Black Sabbath Vol. 4 (Remaster)', 'Album'),
#  ('Black Satin', 'Track'),
#  ('Black Velveteen', 'Track'),
#  ('Blackened', 'Track'),
#  ('Blanco', 'Track'),
#  ('Bleed The Freak', 'Track'),
#  ('Bleed Together', 'Track'),
#  ('Bleeding Me', 'Track'),
#  ('Blew', 'Track'),
#  ('Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold', 'Track'),
#  ('Blind Man', 'Track'),
#  ('Blinded By Rainbows', 'Track'),
#  ('Blissed & Gone', 'Track'),
#  ('Blitzkrieg', 'Track'),
#  ('Blizzard of Ozz', 'Album'),
#  ('Blood', 'Track'),
#  ('Blood Brothers', 'Track'),
#  ('Blood In The Wall', 'Track'),
#  ("Blood On The World's Hands", 'Track'),
#  ('Blood Sugar Sex Magik', 'Album'),
#  ('Blood Sugar Sex Magik', 'Track'),
#  ('Bloodsucker', 'Track'),
#  ('Blow Up The Outside World', 'Track'),
#  ('Blow Your Mind', 'Track'),
#  ('Blue Moods', 'Album'),
#  ('Blue Rythm Fantasy', 'Track'),
#  ('Blue Train', 'Track'),
#  ('Blues Da Piedade', 'Track'),
#  ('Blues For Pablo', 'Track'),
#  ('Blues For Pablo (Alternate Take)', 'Track'),
#  ('Boa Noite', 'Track'),
#  ('Bodies', 'Track'),
#  ('Body Count', 'Album'),
#  ('Body Count', 'Track'),
#  ('Body Count Anthem', 'Track'),
#  ("Body Count's In The House", 'Track'),
#  ('Bohemian Rhapsody', 'Track'),
#  ('Bongo Fury', 'Album'),
#  ("Bonzo's Montreux", 'Track'),
#  ('Boogie Blues', 'Track'),
#  ('Boogie With Stu', 'Track'),
#  ('Book Of Thel', 'Track'),
#  ('Book of Hours', 'Track'),
#  ('Booze Cruise', 'Track'),
#  ('Bop Boogie', 'Track'),
#  ('Bora-Bora', 'Track'),
#  ('Bored To Tears', 'Track'),
#  ('Boris The Spider', 'Track'),
#  ('Born On The Bayou', 'Track'),
#  ('Born To Booze', 'Track'),
#  ('Born To Move', 'Track'),
#  ('Born to Run', 'Track'),
#  ('Borogodo', 'Track'),
#  ('Bossa', 'Track'),
#  ('Boulevard Of Broken Dreams', 'Track'),
#  ('Bowels Of The Devil', 'Track'),
#  ('Boys and Girls', 'Track'),
#  ('Brain Damage', 'Track'),
#  ('Brain Stew', 'Track'),
#  ('Branch Closing', 'Track'),
#  ('Brand New Car', 'Track'),
#  ('Brasil', 'Track'),
#  ('Brasília 5:31', 'Track'),
#  ('Brave New World', 'Album'),
#  ('Brave New World', 'Track'),
#  ('Breadfan', 'Track'),
#  ('Break on Through', 'Track'),
#  ('Breakdown', 'Track'),
#  ('Breakfast In Bed', 'Track'),
#  ('Breaking The Girl', 'Track'),
#  ('Breaking The Law (Live)', 'Track'),
#  ('Breaking The Rules', 'Track'),
#  ('Breakthru', 'Track'),
#  ('Breathe', 'Track'),
#  ('Breed', 'Track'),
#  ('Brejo Da Cruz', 'Track'),
#  ('Brighter Than a Thousand Suns', 'Track'),
#  ('Bring It On Home', 'Track'),
#  ('Bring Me Your Cup', 'Track'),
#  ('Bring Your Daughter... ...To The Slaughter', 'Track'),
#  ('Bring Your Daughter... To The Slaughter', 'Track'),
#  ('Bring Your Daughter... To The Slaughter...', 'Track'),
#  ("Bring'em Back Alive", 'Track'),
#  ("Bringin' On The Heartbreak", 'Track'),
#  ('Broken City', 'Track'),
#  ('Bron-Y-Aur Stomp', 'Track'),
#  ('Bron-Yr-Aur', 'Track'),
#  ('Brumário', 'Track'),
#  ('Buk-In-Hamm Palace', 'Track'),
#  ('Bullet The Blue Sky', 'Track'),
#  ('Bullet With Butterfly Wings', 'Track'),
#  ('Bumbo Da Mangueira', 'Track'),
#  ('Burden In My Hand', 'Track'),
#  ('Burn', 'Track'),
#  ('Burn Away', 'Track'),
#  ('Burning Up', 'Track'),
#  ('Busca Vida', 'Track'),
#  ('Bush Doctor', 'Track'),
#  ('Bushleager', 'Track'),
#  ('Business School', 'Track'),
#  ('Butterfly', 'Track'),
#  ('By The Way', 'Album'),
#  ('By The Way', 'Track'),
#  ('By-Tor And The Snow Dog', 'Track'),
#  ('Bye Bye Blackbird', 'Track'),
#  ('Bye, Bye Brasil', 'Track'),
#  ('Bê-a-Bá', 'Track'),
#  ("C'Mon Everybody", 'Track'),
#  ("C'est La Vie", 'Track'),
#  ('C.O.D.', 'Track'),
#  ('Cabeça Dinossauro', 'Track'),
#  ('Cabin Fever', 'Track'),
#  ('Cabron', 'Track'),
#  ('Cada Um Cada Um (A Namoradeira)', 'Track'),
#  ('Cafezinho', 'Album'),
#  ('Cafezinho', 'Track'),
#  ('Caffeine', 'Track'),
#  ('Cajueiro', 'Track'),
#  ('Cake: B-Sides and Rarities', 'Album'),
#  ('Caleidoscópio', 'Track'),
#  ('Californication', 'Album'),
#  ('Californication', 'Track'),
#  ('Call Me At Cleo´s', 'Track'),
#  ('Call Me a Dog', 'Track'),
#  ('Call Of The Wild', 'Track'),
#  ('Calling Dr. Love', 'Track'),
#  ('Camarão que Dorme e Onda Leva', 'Track'),
#  ('Camisa Verde 2001', 'Track'),
#  ('Can I Play With Madness', 'Track'),
#  ('Can You See Me', 'Track'),
#  ("Can't Get There From Here", 'Track'),
#  ("Can't Get This Stuff No More", 'Track'),
#  ("Can't Get You Off My Mind", 'Track'),
#  ("Can't Keep", 'Track'),
#  ("Can't Stand Losing You", 'Track'),
#  ("Can't Stop", 'Track'),
#  ("Can't Stop Loving You", 'Track'),
#  ('Candy Store Rock', 'Track'),
#  ('Canned Heat', 'Track'),
#  ('Canon and Gigue in D Major: I. Canon', 'Track'),
#  ('Canta, Canta Mais', 'Track'),
#  ('Canto De Ossanha', 'Track'),
#  ('Canário Do Reino', 'Track'),
#  ('Canção Do Novo Mundo', 'Track'),
#  ('Canção Noturna', 'Track'),
#  ('Caprichosos', 'Track'),
#  ('Caralho Voador', 'Track'),
#  ('Caras Como Eu', 'Track'),
#  ('Carimbo', 'Track'),
#  ('Carmen: Overture', 'Track'),
#  ('Carmina Burana', 'Album'),
#  ('Carmina Burana: O Fortuna', 'Track'),
#  ('Carnaval 2001', 'Album'),
#  ('Carnival Of Sorts', 'Track'),
#  ('Carol', 'Track'),
#  ('Carolina', 'Track'),
#  ('Carolina Hard-Core Ecstasy', 'Track'),
#  ('Carouselambra', 'Track'),
#  ('Carpe Diem Baby', 'Track'),
#  ('Carried to Dust (Bonus Track Version)', 'Album'),
#  ('Carry On', 'Album'),
#  ('Carta Ao Tom 74', 'Track'),
#  ('Cartao Postal', 'Track'),
#  ('Casa', 'Track'),
#  ('Casa no Campo', 'Track'),
#  ("Cascades : I'm Not Your Lover", 'Track'),
#  ('Casinha Feliz', 'Track'),
#  ('Casino Night - Season Finale', 'Track'),
#  ('Caso Você Queira Saber', 'Track'),
#  ('Catch-22', 'Track'),
#  ('Cathedral', 'Track'),
#  ('Catimbo', 'Track'),
#  ('Caught Somewhere in Time', 'Track'),
#  ('Cavalleria Rusticana \\ Act \\ Intermezzo Sinfonico', 'Track'),
#  ('Caxangá', 'Track'),
#  ('Caçador de Mim (Sá & Guarabyra)', 'Track'),
#  ('Celebration Day', 'Track'),
#  ('Cesta Básica', 'Album'),
#  ('Chains Of Misery', 'Track'),
#  ('Changes', 'Track'),
#  ('Chaos-Control', 'Track'),
#  ('Chapa o Coco', 'Track'),
#  ('Charles Anjo 45', 'Track'),
#  ('Charpentier: Divertissements, Airs & Concerts', 'Album'),
#  ('Chega no Suingue', 'Track'),
#  ('Chemical Wedding', 'Album'),
#  ('Chemical Wedding', 'Track'),
#  ('Cherub Rock', 'Track'),
#  ('Chico Não Vai na Corimba', 'Track'),
#  ('Child In Time', 'Track'),
#  ('Child In Time (Son Of Aleric - Instrumental)', 'Track'),
#  ("Childhood's End", 'Track'),
#  ('Childhoods End?', 'Track'),
#  ('Children Of The Damned', 'Track'),
#  ('Children Of The Grave', 'Track'),
#  ('Children of the Damned', 'Track'),
#  ('Chill: Brazil (Disc 1)', 'Album'),
#  ('Chill: Brazil (Disc 2)', 'Album'),
#  ('Chocolate', 'Track'),
#  ('Chopin: Piano Concertos Nos. 1 & 2', 'Album'),
#  ('Choramingando', 'Track'),
#  ('Christmas Party', 'Track'),
#  ('Chronicle, Vol. 1', 'Album'),
#  ('Chronicle, Vol. 2', 'Album'),
#  ('Chuva No Brejo', 'Track'),
#  ('Chão De Estrelas', 'Track'),
#  ('Chão de Giz (Elba Ramalho)', 'Track'),
#  ('Cidade', 'Track'),
#  ('Cidade Negra - Hits', 'Album'),
#  ('Cigano', 'Track'),
#  ('Cigaro', 'Track'),
#  ('Cinema Mudo', 'Track'),
#  ('Circles', 'Track'),
#  ('City Of Blinding Lights', 'Track'),
#  ('Civil War', 'Track'),
#  ('Clash City Rockers', 'Track'),
#  ('Closer To The Heart', 'Track'),
#  ('Cocaine', 'Track'),
#  ('Cochise', 'Track'),
#  ('Cocktails', 'Track'),
#  ('Coda', 'Album'),
#  ('Cold Day In The Sun', 'Track'),
#  ('Cold Gin', 'Track'),
#  ('Cold Hard Bitch', 'Track'),
#  ('Cold Sweat', 'Track'),
#  ('Cold Turkey', 'Track'),
#  ('Colibri', 'Track'),
#  ('Collaborators', 'Track'),
#  ('Collision', 'Track'),
#  ('Com A Perna No Mundo', 'Track'),
#  ('Com Açúcar E Com Afeto', 'Track'),
#  ('Coma', 'Track'),
#  ('Comatose', 'Track'),
#  ('Come And Get Some Of This', 'Track'),
#  ('Come Around Again', 'Track'),
#  ('Come As You Are', 'Track'),
#  ('Come Back', 'Track'),
#  ('Come Fly With Me', 'Track'),
#  ('Come Taste The Band', 'Album'),
#  ('Começaria Tudo Outra Vez', 'Track'),
#  ('Começaria Tudo Outra Vez (Maria Creuza)', 'Track'),
#  ('Comida', 'Track'),
#  ("Comin' Home", 'Track'),
#  ('Coming In Hot', 'Track'),
#  ('Commercial 1', 'Track'),
#  ('Commercial 2', 'Track'),
#  ('Commotion', 'Track'),
#  ('Communication Breakdown', 'Track'),
#  ('Communication Breakdown(2)', 'Track'),
#  ('Communication Breakdown(3)', 'Track'),
#  ('Como Estais Amigos', 'Track'),
#  ('Como É Duro Trabalhar', 'Track'),
#  ('Compadre', 'Track'),
#  ('Company Man', 'Track'),
#  ('Complete Control', 'Track'),
#  ('Comportamento Geral', 'Track'),
#  ('Compositores', 'Album'),
#  ('Compulsion', 'Track'),
#  ('Computadores Fazem Arte', 'Track'),
#  ('Concert pour 4 Parties de V**les, H. 545: I. Prelude', 'Track'),
#  ('Concerto No. 1 in E Major, RV 269 "Spring": I. Allegro', 'Track'),
#  ('Concerto No.2 in F Major, BWV1047, I. Allegro', 'Track'),
#  ('Concerto for 2 Violins in D Minor, BWV 1043: I. Vivace', 'Track'),
#  ('Concerto for Cello and Orchestra in E minor, Op. 85: I. Adagio - Moderato', 'Track'),
#  ('Concerto for Clarinet in A Major, K. 622: II. Adagio', 'Track'),
#  ('Concerto for Piano No. 2 in F Minor, Op. 21: II. Larghetto', 'Track'),
#  ('Concerto for Violin, Strings and Continuo in G Major, Op. 3, No. 9: I. Allegro', 'Track'),
#  ('Conciliação', 'Track'),
#  ('Condição', 'Track'),
#  ('Confidence Man', 'Track'),
#  ('Confidência', 'Track'),
#  ('Confirmed Dead', 'Track'),
#  ('Conflict Resolution', 'Track'),
#  ('Confusion', 'Track'),
#  ('Construção / Deus Lhe Pague', 'Track'),
#  ('Contraband', 'Album'),
#  ('Copacabana (Live)', 'Track'),
#  ('Corazon Espinado', 'Track'),
#  ('Coração De Estudante', 'Track'),
#  ('Coração Em Desalinho', 'Track'),
#  ('Coração do Agreste (Fafá de Belém)', 'Track'),
#  ('Corcovado (Quiet Nights Of Quiet Stars)', 'Track'),
#  ('Corduroy', 'Track'),
#  ('Core', 'Album'),
#  ('Corinna', 'Track'),
#  ('Cornucopia', 'Track'),
#  ('Coronation Drop', 'Track'),
#  ('Coroné Antonio Bento', 'Track'),
#  ('Corpo De Lama', 'Track'),
#  ('Corpse (These Chains Are Way Too Long)', 'Track'),
#  ('Cosmic Fiend', 'Track'),
#  ('Cotidiano N 2', 'Track'),
#  ('Cotton Fields', 'Track'),
#  ('Country Feedback', 'Track'),
#  ('Crack Hitler', 'Track'),
#  ('Crackerman', 'Track'),
#  ('Crash Course In Brain Surgery', 'Track'),
#  ('Crazy', 'Track'),
#  ('Crazy Little Thing Called Love', 'Track'),
#  ('Crazy Train', 'Track'),
#  ('Creep', 'Track'),
#  ('Creeping Death', 'Track'),
#  ('Criança De Domingo', 'Track'),
#  ('Cristina Nº 2', 'Track'),
#  ('Cropduster', 'Track'),
#  ('Crossfire', 'Track'),
#  ('Crossroads', 'Track'),
#  ('Crossroads, Pt. 1', 'Track'),
#  ('Crossroads, Pt. 2', 'Track'),
#  ('Crumbs From Your Table', 'Track'),
#  ('Crushing Day', 'Track'),
#  ('Cry For Love', 'Track'),
#  ("Cryin'", 'Track'),
#  ('Crying In The Rain', 'Track'),
#  ('Crystal Ball', 'Track'),
#  ('Cuando A Noite Vai Chegando', 'Track'),
#  ('Cuando Eu For Pro Ceu', 'Track'),
#  ('Cucamonga', 'Track'),
#  ('Cuckoo For Caca', 'Track'),
#  ('Cuitelinho', 'Track'),
#  ('Cure', 'Track'),
#  ('Cursed Diamonds', 'Track'),
#  ('Custard Pie', 'Track'),
#  ('Cuyahoga', 'Track'),
#  ('Cássia Eller - Coleção Sem Limite [Disc 2]', 'Album'),
#  ('Cássia Eller - Sem Limite [Disc 1]', 'Album'),
#  ('Cérebro Eletrônico', 'Track'),
#  ('Cérebro Eletrônico (Live)', 'Track'),
#  ('D Note', 'Track'),
#  ("D'Yer Mak'er", 'Track'),
#  ('D.O.C.', 'Track'),
#  ('DOA', 'Track'),
#  ('Da Lama Ao Caos', 'Album'),
#  ('Da Lama Ao Caos', 'Track'),
#  ("Daddy's Gonna Pay For Your Crashed Car", 'Track'),
#  ('Damage Case', 'Track'),
#  ('Damage Inc.', 'Track'),
#  ('Dance', 'Track'),
#  ('Dance Enquanto é Tempo', 'Track'),
#  ('Dance Of Death', 'Album'),
#  ('Dance Of Death', 'Track'),
#  ('Dance the Night Away', 'Track'),
#  ('Dancing Barefoot', 'Track'),
#  ('Dancing Days', 'Track'),
#  ('Dancing In The Street', 'Track'),
#  ('Dancin´Days', 'Track'),
#  ('Dandelion', 'Track'),
#  ('Daniela', 'Track'),
#  ('Danny Boy, Danny Boy', 'Track'),
#  ('Dança Da Solidão', 'Track'),
#  ('Dark Corners', 'Track'),
#  ('Dark Side Of The Cog', 'Track'),
#  ('Dark Side Of The Moon', 'Album'),
#  ('Darlene', 'Track'),
#  ('Das Lied Von Der Erde, Von Der Jugend', 'Track'),
#  ('Daughter', 'Track'),
#  ('Dave', 'Track'),
#  ('Dazed And Confused', 'Track'),
#  ('Dazed and Confused', 'Track'),
#  ('De Do Do Do, De Da Da Da', 'Track'),
#  ('De Ja Vu', 'Track'),
#  ('De La Luz', 'Track'),
#  ('De Noite Na Cama', 'Track'),
#  ('De Ouro E Marfim (Live)', 'Track'),
#  ('Dead And Bloated', 'Track'),
#  ('Dead And Broken', 'Track'),
#  ('Dead Horse', 'Track'),
#  ('Dealer', 'Track'),
#  ('Debra Kadabra', 'Track'),
#  ('Dee', 'Track'),
#  ('Deep', 'Track'),
#  ('Deep Purple In Rock', 'Album'),
#  ('Deep Waters', 'Track'),
#  ('Deeper Underground', 'Track'),
#  ('Deixa', 'Track'),
#  ('Deixa Entrar', 'Album'),
#  ('Deixa Entrar', 'Track'),
#  ('Demorou!', 'Track'),
#  ('Demorou...', 'Album'),
#  ('Denúncia', 'Track'),
#  ('Departure', 'Track'),
#  ('Desafinado', 'Track'),
#  ('Desaforo', 'Track'),
#  ('Desculpe Babe', 'Track'),
#  ('Desire', 'Track'),
#  ('Desordem', 'Track'),
#  ('Despertar', 'Track'),
#  ('Destitute Illusions', 'Track'),
#  ('Detroit Rock City', 'Track'),
#  ('Deuce', 'Track'),
#  ('Deuces Are Wild', 'Track'),
#  ('Deus', 'Track'),
#  ('Deus Ex Machina', 'Track'),
#  ("Devil's Dance", 'Track'),
#  ('Dezesseis', 'Track'),
#  ('Diamante De Mendigo', 'Track'),
#  ('Diamonds And Rust (Live)', 'Track'),
#  ('Diary of a Madman (Remastered)', 'Album'),
#  ("Didgin' Out", 'Track'),
#  ('Die Die My Darling', 'Track'),
#  ('Die Walküre: The Ride of the Valkyries', 'Track'),
#  ('Die With Your Boots On', 'Track'),
#  ('Die Zauberflöte, K.620: "Der Hölle Rache Kocht in Meinem Herze"', 'Track'),
#  ('Different World', 'Track'),
#  ('Dig-Dig, Lambe-Lambe (Ao Vivo)', 'Track'),
#  ('Diga Lá, Coração', 'Track'),
#  ('Digging The Grave', 'Track'),
#  ('Din Din Wo (Little Child)', 'Track'),
#  ('Dindi (Dindi)', 'Track'),
#  ('Dirty Day', 'Track'),
#  ('Dirty Hands', 'Track'),
#  ('Dirty Little Thing', 'Track'),
#  ('Dirty Love', 'Track'),
#  ('Dirty Water Dog', 'Track'),
#  ('Dirty Window', 'Track'),
#  ('Disappearing Act', 'Track'),
#  ('Disarm', 'Track'),
#  ('Disc Jockey Jump', 'Track'),
#  ('Discotheque', 'Track'),
#  ('Disenchanted Lullaby', 'Track'),
#  ('Disposable Heroes', 'Track'),
#  ('Dissident', 'Track'),
#  ('Distance', 'Track'),
#  ('Distractions', 'Track'),
#  ('Diver Down', 'Album'),
#  ('Diversity Day', 'Track'),
#  ('Diversão', 'Track'),
#  ('Divirta-Se (Saindo Da Sua)', 'Track'),
#  ('Diwali', 'Track'),
#  ('Djavan Ao Vivo - Vol. 02', 'Album'),
#  ('Djavan Ao Vivo - Vol. 1', 'Album'),
#  ('Do It For The Kids', 'Track'),
#  ('Do No Harm', 'Track'),
#  ('Do Nosso Amor', 'Track'),
#  ('Do The Evolution', 'Track'),
#  ('Do You Feel Loved', 'Track'),
#  ('Do You Have Other Loves?', 'Track'),
#  ('Do You Like The Way', 'Track'),
#  ('Do You Love Me', 'Track'),
#  ('Do what cha wanna', 'Track'),
#  ('Doce De Carnaval (Candy All)', 'Track'),
#  ("Doesn't Remind Me", 'Track'),
#  ('Dog Eat Dog', 'Track'),
#  ('Dois Pra Lá, Dois Pra Cá', 'Track'),
#  ('Dois Índios', 'Track'),
#  ('Doll', 'Track'),
#  ('Domingo', 'Track'),
#  ('Domino', 'Track'),
#  ("Don't Cry", 'Track'),
#  ("Don't Cry (Original)", 'Track'),
#  ("Don't Damn Me", 'Track'),
#  ("Don't Forget Me", 'Track'),
#  ("Don't Go Away Mad (Just Go Away)", 'Track'),
#  ("Don't Go Back To Rockville", 'Track'),
#  ("Don't Lie To Me", 'Track'),
#  ("Don't Look Back", 'Track'),
#  ("Don't Look Now", 'Track'),
#  ("Don't Look To The Eyes Of A Stranger", 'Track'),
#  ("Don't Stand So Close to Me '86", 'Track'),
#  ("Don't Stand so Close to Me", 'Track'),
#  ("Don't Stop Me Now", 'Track'),
#  ("Don't Take Your Love From Me", 'Track'),
#  ("Don't Tread On Me", 'Track'),
#  ("Don't You Cry", 'Track'),
#  ('Dona (Roupa Nova)', 'Track'),
#  ('Dosed', 'Track'),
#  ("Double Talkin' Jive", 'Track'),
#  ('Doutor', 'Track'),
#  ('Down By The Seaside', 'Track'),
#  ('Down On The Corner', 'Track'),
#  ('Down Under', 'Track'),
#  ('Down by the Sea', 'Track'),
#  ('Downtown', 'Track'),
#  ('Dr. Feelgood', 'Track'),
#  ('Dr. Heckyll & Mr. Jive', 'Track'),
#  ('Drain You', 'Track'),
#  ('Dream Of Mirrors', 'Track'),
#  ('Dreams', 'Track'),
#  ('Drifter', 'Track'),
#  ('Driver 8', 'Track'),
#  ('Drown', 'Track'),
#  ('Drown Me Slowly', 'Track'),
#  ('Drowning Man', 'Track'),
#  ('Drug Testing', 'Track'),
#  ('Drum Boogie', 'Track'),
#  ('Drão', 'Track'),
#  ('Dude (Looks Like A Lady)', 'Track'),
#  ('Duelists', 'Track'),
#  ('Duende', 'Track'),
#  ('Dujji', 'Track'),
#  ('Duos II', 'Album'),
#  ("Dust N' Bones", 'Track'),
#  ("Dwight's Speech", 'Track'),
#  ('Dyers Eve', 'Track'),
#  ('E Vamos À Luta', 'Track'),
#  ('E-Bow The Letter', 'Track'),
#  ('E.C.T.', 'Track'),
#  ('E.S.P.', 'Track'),
#  ('Earth Mofo', 'Track'),
#  ('Easily', 'Track'),
#  ('Easy', 'Track'),
#  ('Eat The Rich', 'Track'),
#  ('Echo', 'Track'),
#  ('Eclipse', 'Track'),
#  ('Eclipse Oculto', 'Track'),
#  ('Edge Of The World', 'Track'),
#  ('Edie (Ciao Baby)', 'Track'),
#  ('Eduardo E Mônica', 'Track'),
#  ('Eggtown', 'Track'),
#  ('Ego Tripping Out', 'Track'),
#  ('El Corazon Manda', 'Track'),
#  ('El Farol', 'Track'),
#  ('Ela Desapareceu', 'Track'),
#  ('Ela Disse Adeus', 'Track'),
#  ('Elderly Woman Behind The Counter In A Small Town', 'Track'),
#  ('Eleanor Rigby', 'Track'),
#  ('Electric Eye', 'Track'),
#  ('Electrolite', 'Track'),
#  ('Elevation', 'Track'),
#  ('Elgar: Cello Concerto & Vaughan Williams: Fantasias', 'Album'),
#  ('Elis Regina-Minha História', 'Album'),
#  ('Elvis Ate America', 'Track'),
#  ('Elza', 'Track'),
#  ('Email Surveillance', 'Track'),
#  ('Emerald', 'Track'),
#  ('Emergency', 'Track'),
#  ('Emergency On Planet Earth', 'Album'),
#  ('Emergency On Planet Earth', 'Track'),
#  ('Emit Remmus', 'Track'),
#  ('Encontrar Alguém', 'Track'),
#  ('End Of Romanticism', 'Track'),
#  ('End Of The Night', 'Track'),
#  ('End Over End', 'Track'),
#  ('Endgame', 'Track'),
#  ('Endless Deep', 'Track'),
#  ('Engenho De Dentro', 'Track'),
#  ('English Civil War', 'Track'),
#  ('English Renaissance', 'Album'),
#  ('Enough Space', 'Track'),
#  ('Enquanto O Dia Não Vem', 'Track'),
#  ('Enquanto O Mundo Explode', 'Track'),
#  ('Enslaved', 'Track'),
#  ('Enter 77', 'Track'),
#  ('Enter Sandman', 'Track'),
#  ('Entrando Na Sua (Intro)', 'Track'),
#  ('Entre E Ouça', 'Track'),
#  ('Epic', 'Track'),
#  ('Equal Rights Downpresser Man', 'Track'),
#  ('Equinocio', 'Track'),
#  ('Era Uma Vez', 'Track'),
#  ('Erlkonig, D.328', 'Track'),
#  ('Eruption', 'Track'),
#  ('Escape', 'Track'),
#  ('Esotérico', 'Track'),
#  ('Esperando Na Janela', 'Track'),
#  ('Esperando Por Mim', 'Track'),
#  ('Espere Por Mim, Morena', 'Track'),
#  ('Esporrei Na Manivela', 'Track'),
#  ('Esquinas', 'Track'),
#  ('Essa Moça Ta Diferente', 'Track'),
#  ('Esse Cara', 'Track'),
#  ('Esta É A Canção', 'Track'),
#  ('Estranged', 'Track'),
#  ('Estrela (Live)', 'Track'),
#  ('Etnia', 'Track'),
#  ('Eu Amo Você', 'Track'),
#  ('Eu Apenas Queria Que Voçê Soubesse', 'Track'),
#  ('Eu Disse A Ela', 'Track'),
#  ('Eu E Ela', 'Track'),
#  ('Eu So Queria Sumir', 'Track'),
#  ('Eu Sou Neguinha (Ao Vivo)', 'Track'),
#  ('Eu Também Quero Beijar', 'Track'),
#  ('Eu Te Devoro', 'Track'),
#  ('Eu Vim Da Bahia - Live', 'Track'),
#  ('Even Better Than The Real Thing', 'Track'),
#  ('Even Flow', 'Track'),
#  ('Evenflow', 'Track'),
#  ('Everlasting Love', 'Track'),
#  ('Everlong', 'Track'),
#  ('Every Breath You Take', 'Track'),
#  ('Every Kind of Light', 'Album'),
#  ('Every Little Thing She Does is Magic', 'Track'),
#  ('Every Man for Himself', 'Track'),
#  ('Every Time I Look At You', 'Track'),
#  ('Everybody Hates Hugo', 'Track'),
#  ('Everything I Need', 'Track'),
#  ("Everything's Ruined", 'Track'),
#  ('Evidence', 'Track'),
#  ('Evil Dick', 'Track'),
#  ('Evil Walks', 'Track'),
#  ('Evil Ways', 'Track'),
#  ('Evil Woman', 'Track'),
#  ('Exodus (Part 1)', 'Track'),
#  ('Exodus (Part 2) [Season Finale]', 'Track'),
#  ('Exodus (Part 3) [Season Finale]', 'Track'),
#  ('Exodus, Pt. 1', 'Track'),
#  ('Exodus, Pt. 2', 'Track'),
#  ...]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///Northwind.db

# %%
# %%sql
#
# SELECT
#     product.ProductName,
#     supplier.CompanyName
# FROM
#     Products AS product
# INNER JOIN
#     Suppliers AS supplier
#     ON product.SupplierID = supplier.SupplierID;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///Northwind.db
#    sqlite:///chinook.db
# Done.
# [('Chai', 'Exotic Liquids'),
#  ('Chang', 'Exotic Liquids'),
#  ('Aniseed Syrup', 'Exotic Liquids'),
#  ("Chef Anton's Cajun Seasoning", 'New Orleans Cajun Delights'),
#  ("Chef Anton's Gumbo Mix", 'New Orleans Cajun Delights'),
#  ("Grandma's Boysenberry Spread", "Grandma Kelly's Homestead"),
#  ("Uncle Bob's Organic Dried Pears", "Grandma Kelly's Homestead"),
#  ('Northwoods Cranberry Sauce', "Grandma Kelly's Homestead"),
#  ('Mishi Kobe Niku', 'Tokyo Traders'),
#  ('Ikura', 'Tokyo Traders'),
#  ('Queso Cabrales', "Cooperativa de Quesos 'Las Cabras'"),
#  ('Queso Manchego La Pastora', "Cooperativa de Quesos 'Las Cabras'"),
#  ('Konbu', "Mayumi's"),
#  ('Tofu', "Mayumi's"),
#  ('Genen Shouyu', "Mayumi's"),
#  ('Pavlova', 'Pavlova, Ltd.'),
#  ('Alice Mutton', 'Pavlova, Ltd.'),
#  ('Carnarvon Tigers', 'Pavlova, Ltd.'),
#  ('Teatime Chocolate Biscuits', 'Specialty Biscuits, Ltd.'),
#  ("Sir Rodney's Marmalade", 'Specialty Biscuits, Ltd.'),
#  ("Sir Rodney's Scones", 'Specialty Biscuits, Ltd.'),
#  ("Gustaf's Knckebrd", 'PB Knckebrd AB'),
#  ('Tunnbrd', 'PB Knckebrd AB'),
#  ('Guaran Fantstica', 'Refrescos Americanas LTDA'),
#  ('NuNuCa Nu-Nougat-Creme', 'Heli Swaren GmbH & Co. KG'),
#  ('Gumbr Gummibrchen', 'Heli Swaren GmbH & Co. KG'),
#  ('Schoggi Schokolade', 'Heli Swaren GmbH & Co. KG'),
#  ('Rssle Sauerkraut', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Thringer Rostbratwurst', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Nord-Ost Matjeshering', 'Nord-Ost-Fisch Handelsgesellschaft mbH'),
#  ('Gorgonzola Telino', 'Formaggi Fortini s.r.l.'),
#  ('Mascarpone Fabioli', 'Formaggi Fortini s.r.l.'),
#  ('Geitost', 'Norske Meierier'),
#  ('Sasquatch Ale', 'Bigfoot Breweries'),
#  ('Steeleye Stout', 'Bigfoot Breweries'),
#  ('Inlagd Sill', 'Svensk Sjfda AB'),
#  ('Gravad lax', 'Svensk Sjfda AB'),
#  ('Cte de Blaye', 'Aux joyeux ecclsiastiques'),
#  ('Chartreuse verte', 'Aux joyeux ecclsiastiques'),
#  ('Boston Crab Meat', 'New England Seafood Cannery'),
#  ("Jack's New England Clam Chowder", 'New England Seafood Cannery'),
#  ('Singaporean Hokkien Fried Mee', 'Leka Trading'),
#  ('Ipoh Coffee', 'Leka Trading'),
#  ('Gula Malacca', 'Leka Trading'),
#  ('Rogede sild', 'Lyngbysild'),
#  ('Spegesild', 'Lyngbysild'),
#  ('Zaanse koeken', 'Zaanse Snoepfabriek'),
#  ('Chocolade', 'Zaanse Snoepfabriek'),
#  ('Maxilaku', 'Karkki Oy'),
#  ('Valkoinen suklaa', 'Karkki Oy'),
#  ('Manjimup Dried Apples', "G'day, Mate"),
#  ('Filo Mix', "G'day, Mate"),
#  ('Perth Pasties', "G'day, Mate"),
#  ('Tourtire', 'Ma Maison'),
#  ('Pt chinois', 'Ma Maison'),
#  ('Gnocchi di nonna Alice', 'Pasta Buttini s.r.l.'),
#  ('Ravioli Angelo', 'Pasta Buttini s.r.l.'),
#  ('Escargots de Bourgogne', 'Escargots Nouveaux'),
#  ('Raclette Courdavault', 'Gai pturage'),
#  ('Camembert Pierrot', 'Gai pturage'),
#  ("Sirop d'rable", "Forts d'rables"),
#  ('Tarte au sucre', "Forts d'rables"),
#  ('Vegie-spread', 'Pavlova, Ltd.'),
#  ('Wimmers gute Semmelkndel', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Louisiana Fiery Hot Pepper Sauce', 'New Orleans Cajun Delights'),
#  ('Louisiana Hot Spiced Okra', 'New Orleans Cajun Delights'),
#  ('Laughing Lumberjack Lager', 'Bigfoot Breweries'),
#  ('Scottish Longbreads', 'Specialty Biscuits, Ltd.'),
#  ('Gudbrandsdalsost', 'Norske Meierier'),
#  ('Outback Lager', 'Pavlova, Ltd.'),
#  ('Flotemysost', 'Norske Meierier'),
#  ('Mozzarella di Giovanni', 'Formaggi Fortini s.r.l.'),
#  ('Rd Kaviar', 'Svensk Sjfda AB'),
#  ('Longlife Tofu', 'Tokyo Traders'),
#  ('Rhnbru Klosterbier', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Lakkalikri', 'Karkki Oy'),
#  ('Original Frankfurter grne Soe', 'Plutzer Lebensmittelgromrkte AG')]

# %%
# %%sql
#
# SELECT City FROM Customers;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///Northwind.db
#    sqlite:///chinook.db
# Done.
# [('Berlin',),
#  ('Mxico D.F.',),
#  ('Mxico D.F.',),
#  ('London',),
#  ('Lule',),
#  ('Mannheim',),
#  ('Strasbourg',),
#  ('Madrid',),
#  ('Marseille',),
#  ('Tsawassen',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Mxico D.F.',),
#  ('Bern',),
#  ('Sao Paulo',),
#  ('London',),
#  ('Aachen',),
#  ('Nantes',),
#  ('London',),
#  ('Graz',),
#  ('Sao Paulo',),
#  ('Madrid',),
#  ('Lille',),
#  ('Brcke',),
#  ('Mnchen',),
#  ('Nantes',),
#  ('Torino',),
#  ('Lisboa',),
#  ('Barcelona',),
#  ('Sevilla',),
#  ('Campinas',),
#  ('Eugene',),
#  ('Caracas',),
#  ('Rio de Janeiro',),
#  ('San Cristbal',),
#  ('Elgin',),
#  ('Cork',),
#  ('Cowes',),
#  ('Brandenburg',),
#  ('Versailles',),
#  ('Toulouse',),
#  ('Vancouver',),
#  ('Walla Walla',),
#  ('Frankfurt a.M.',),
#  ('San Francisco',),
#  ('Barquisimeto',),
#  ('I. de Margarita',),
#  ('Portland',),
#  ('Bergamo',),
#  ('Bruxelles',),
#  ('Montral',),
#  ('Leipzig',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Anchorage',),
#  ('Kln',),
#  ('Paris',),
#  ('Mxico D.F.',),
#  ('Salzburg',),
#  ('Lisboa',),
#  ('Rio de Janeiro',),
#  ('Sao Paulo',),
#  ('Cunewalde',),
#  ('Buenos Aires',),
#  ('Albuquerque',),
#  ('Reggio Emilia',),
#  ('Rio de Janeiro',),
#  ('Genve',),
#  ('Madrid',),
#  ('Stavern',),
#  ('Boise',),
#  ('London',),
#  ('Kobenhavn',),
#  ('Paris',),
#  ('Lander',),
#  ('Charleroi',),
#  ('Portland',),
#  ('Butte',),
#  ('Mnster',),
#  ('Mxico D.F.',),
#  ('Sao Paulo',),
#  ('Kirkland',),
#  ('rhus',),
#  (None,),
#  (None,),
#  ('Lyon',),
#  ('Reims',),
#  ('Stuttgart',),
#  ('Oulu',),
#  ('Resende',),
#  ('Seattle',),
#  ('Helsinki',),
#  ('Warszawa',)]

# %%
# %%sql
#
# SELECT City FROM Customers
# UNION
# SELECT City FROM Employees;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///Northwind.db
#    sqlite:///chinook.db
# Done.
# [(None,),
#  ('Aachen',),
#  ('Albuquerque',),
#  ('Anchorage',),
#  ('Barcelona',),
#  ('Barquisimeto',),
#  ('Bergamo',),
#  ('Berlin',),
#  ('Bern',),
#  ('Boise',),
#  ('Brandenburg',),
#  ('Brcke',),
#  ('Bruxelles',),
#  ('Buenos Aires',),
#  ('Butte',),
#  ('Campinas',),
#  ('Caracas',),
#  ('Charleroi',),
#  ('Cork',),
#  ('Cowes',),
#  ('Cunewalde',),
#  ('Elgin',),
#  ('Eugene',),
#  ('Frankfurt a.M.',),
#  ('Genve',),
#  ('Graz',),
#  ('Helsinki',),
#  ('I. de Margarita',),
#  ('Kirkland',),
#  ('Kln',),
#  ('Kobenhavn',),
#  ('Lander',),
#  ('Leipzig',),
#  ('Lille',),
#  ('Lisboa',),
#  ('London',),
#  ('Lule',),
#  ('Lyon',),
#  ('Madrid',),
#  ('Mannheim',),
#  ('Marseille',),
#  ('Mnchen',),
#  ('Mnster',),
#  ('Montral',),
#  ('Mxico D.F.',),
#  ('Nantes',),
#  ('Oulu',),
#  ('Paris',),
#  ('Portland',),
#  ('Redmond',),
#  ('Reggio Emilia',),
#  ('Reims',),
#  ('Resende',),
#  ('Rio de Janeiro',),
#  ('Salzburg',),
#  ('San Cristbal',),
#  ('San Francisco',),
#  ('Sao Paulo',),
#  ('Seattle',),
#  ('Sevilla',),
#  ('Stavern',),
#  ('Strasbourg',),
#  ('Stuttgart',),
#  ('Tacoma',),
#  ('Torino',),
#  ('Toulouse',),
#  ('Tsawassen',),
#  ('Vancouver',),
#  ('Versailles',),
#  ('Walla Walla',),
#  ('Warszawa',),
#  ('rhus',)]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:Robinpass123@localhost:3306/united_nations

# %%
# %%sql
#
# SELECT
#     Sub_region,
#     SUM(Land_area) AS Total_Land_Area
# FROM
#     Geographic_location
# GROUP BY
#     Sub_region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 18 rows affected.
# [('Southern Asia', Decimal('4770157.00')),
#  ('Northern Africa', Decimal('6610941.00')),
#  ('Polynesia', Decimal('7251.00')),
#  ('Middle Africa', Decimal('3888270.00')),
#  ('Caribbean', Decimal('208314.00')),
#  ('South America', Decimal('15401392.00')),
#  ('Western Asia', Decimal('3488597.00')),
#  ('Australia and New Zealand', Decimal('7955330.00')),
#  ('Central America', Decimal('2452110.00')),
#  ('Western Africa', Decimal('5735550.00')),
#  ('Northern America', Decimal('9376094.00')),
#  ('Southern Africa', Decimal('2650670.00')),
#  ('South-Eastern Asia', Decimal('3865587.00')),
#  ('Eastern Africa', Decimal('5949171.03')),
#  ('Eastern Asia', Decimal('11346709.70')),
#  ('Melanesia', Decimal('529590.00')),
#  ('Micronesia', Decimal('2470.00')),
#  ('Central Asia', Decimal('3749070.00'))]

# %%
# %%sql
#
# SELECT
#     geoloc.Country_name,
#     geoloc.Land_area,
#     geoloc.Sub_region,
#     (geoloc.Land_area / Land_per_region.Total_Land_Area) * 100 AS Pct_Of_Region_Land
# FROM
#     Geographic_location AS geoloc
# JOIN
#     (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS Total_Land_Area
#     FROM
#         Geographic_location
#     GROUP BY
#         Sub_region)  AS Land_per_region
#     ON
#         geoloc.Sub_region = Land_per_region.sub_Region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 182 rows affected.
# [('Afghanistan', Decimal('652230.00'), 'Southern Asia', Decimal('13.673135')),
#  ('Algeria', Decimal('2381741.00'), 'Northern Africa', Decimal('36.027261')),
#  ('American Samoa', Decimal('200.00'), 'Polynesia', Decimal('2.758240')),
#  ('Angola', Decimal('1246700.00'), 'Middle Africa', Decimal('32.063103')),
#  ('Anguilla', None, 'Caribbean', None),
#  ('Antigua and Barbuda', Decimal('440.00'), 'Caribbean', Decimal('0.211220')),
#  ('Argentina', Decimal('2736690.00'), 'South America', Decimal('17.769108')),
#  ('Armenia', Decimal('28470.00'), 'Western Asia', Decimal('0.816087')),
#  ('Aruba', Decimal('180.00'), 'Caribbean', Decimal('0.086408')),
#  ('Australia', Decimal('7692020.00'), 'Australia and New Zealand', Decimal('96.690144')),
#  ('Azerbaijan', Decimal('82670.00'), 'Western Asia', Decimal('2.369721')),
#  ('Bahamas', None, 'Caribbean', None),
#  ('Bahrain', Decimal('785.00'), 'Western Asia', Decimal('0.022502')),
#  ('Bangladesh', Decimal('130170.00'), 'Southern Asia', Decimal('2.728841')),
#  ('Barbados', Decimal('430.00'), 'Caribbean', Decimal('0.206419')),
#  ('Belize', Decimal('22810.00'), 'Central America', Decimal('0.930219')),
#  ('Benin', Decimal('112760.00'), 'Western Africa', Decimal('1.965984')),
#  ('Bermuda', Decimal('54.00'), 'Northern America', Decimal('0.000576')),
#  ('Bhutan', Decimal('38144.00'), 'Southern Asia', Decimal('0.799638')),
#  ('Bolivia (Plurinational State of)', None, 'South America', None),
#  ('Botswana', Decimal('566730.00'), 'Southern Africa', Decimal('21.380632')),
#  ('Brazil', Decimal('8358140.00'), 'South America', Decimal('54.268731')),
#  ('British Virgin Islands', Decimal('150.00'), 'Caribbean', Decimal('0.072007')),
#  ('Brunei Darussalam', Decimal('5270.00'), 'South-Eastern Asia', Decimal('0.136331')),
#  ('Burkina Faso', Decimal('273600.00'), 'Western Africa', Decimal('4.770249')),
#  ('Burundi', Decimal('25680.00'), 'Eastern Africa', Decimal('0.431657')),
#  ('Cabo Verde', Decimal('4030.00'), 'Western Africa', Decimal('0.070264')),
#  ('Cambodia', Decimal('176520.00'), 'South-Eastern Asia', Decimal('4.566447')),
#  ('Cameroon', Decimal('472710.00'), 'Middle Africa', Decimal('12.157335')),
#  ('Canada', Decimal('8965590.00'), 'Northern America', Decimal('95.621802')),
#  ('Cayman Islands', Decimal('240.00'), 'Caribbean', Decimal('0.115211')),
#  ('Central African Republic', Decimal('622980.00'), 'Middle Africa', Decimal('16.022036')),
#  ('Chad', Decimal('1259200.00'), 'Middle Africa', Decimal('32.384582')),
#  ('Chile', Decimal('743532.00'), 'South America', Decimal('4.827693')),
#  ('China', Decimal('9424702.90'), 'Eastern Asia', Decimal('83.061109')),
#  ('Colombia', Decimal('1109500.00'), 'South America', Decimal('7.203894')),
#  ('Comoros', Decimal('1861.00'), 'Eastern Africa', Decimal('0.031282')),
#  ('Congo', None, 'Middle Africa', None),
#  ('Cook Islands', None, 'Polynesia', None),
#  ('Costa Rica', Decimal('51060.00'), 'Central America', Decimal('2.082288')),
#  ("Côte d'Ivoire", None, 'Western Africa', None),
#  ('Cuba', Decimal('104100.00'), 'Caribbean', Decimal('49.972637')),
#  ('Curaçao', None, 'Caribbean', None),
#  ('Cyprus', Decimal('9240.00'), 'Western Asia', Decimal('0.264863')),
#  ("Democratic People's Republic of Korea", None, 'Eastern Asia', None),
#  ('Democratic Republic of the Congo', None, 'Middle Africa', None),
#  ('Djibouti', Decimal('23180.00'), 'Eastern Africa', Decimal('0.389634')),
#  ('Dominica', Decimal('750.00'), 'Caribbean', Decimal('0.360033')),
#  ('Dominican Republic', Decimal('48310.00'), 'Caribbean', Decimal('23.190952')),
#  ('Ecuador', Decimal('248360.00'), 'South America', Decimal('1.612582')),
#  ('Egypt', None, 'Northern Africa', None),
#  ('El Salvador', Decimal('20720.00'), 'Central America', Decimal('0.844987')),
#  ('Equatorial Guinea', Decimal('28050.00'), 'Middle Africa', Decimal('0.721401')),
#  ('Eritrea', Decimal('121088.77'), 'Eastern Africa', Decimal('2.035389')),
#  ('Eswatini', Decimal('17200.00'), 'Southern Africa', Decimal('0.648893')),
#  ('Ethiopia', Decimal('1128571.26'), 'Eastern Africa', Decimal('18.970227')),
#  ('Falkland Islands (Malvinas)', None, 'South America', None),
#  ('Fiji', Decimal('18270.00'), 'Melanesia', Decimal('3.449839')),
#  ('French Guiana', None, 'South America', None),
#  ('French Polynesia', Decimal('3471.00'), 'Polynesia', Decimal('47.869259')),
#  ('Gabon', Decimal('257670.00'), 'Middle Africa', Decimal('6.626855')),
#  ('Gambia', None, 'Western Africa', None),
#  ('Georgia', Decimal('69490.00'), 'Western Asia', Decimal('1.991918')),
#  ('Ghana', Decimal('227540.00'), 'Western Africa', Decimal('3.967187')),
#  ('Greenland', Decimal('410450.00'), 'Northern America', Decimal('4.377622')),
#  ('Grenada', Decimal('340.00'), 'Caribbean', Decimal('0.163215')),
#  ('Guadeloupe', None, 'Caribbean', None),
#  ('Guam', Decimal('540.00'), 'Micronesia', Decimal('21.862348')),
#  ('Guatemala', Decimal('107160.00'), 'Central America', Decimal('4.370114')),
#  ('Guinea', Decimal('245720.00'), 'Western Africa', Decimal('4.284158')),
#  ('Guinea-Bissau', Decimal('28120.00'), 'Western Africa', Decimal('0.490276')),
#  ('Guyana', Decimal('196850.00'), 'South America', Decimal('1.278131')),
#  ('Haiti', Decimal('27560.00'), 'Caribbean', Decimal('13.230028')),
#  ('Honduras', Decimal('111890.00'), 'Central America', Decimal('4.563009')),
#  ('India', Decimal('2973190.00'), 'Southern Asia', Decimal('62.328976')),
#  ('Indonesia', Decimal('1877519.00'), 'South-Eastern Asia', Decimal('48.570088')),
#  ('Iran (Islamic Republic of)', None, 'Southern Asia', None),
#  ('Iraq', Decimal('434128.00'), 'Western Asia', Decimal('12.444200')),
#  ('Israel', Decimal('21640.00'), 'Western Asia', Decimal('0.620307')),
#  ('Jamaica', Decimal('10830.00'), 'Caribbean', Decimal('5.198882')),
#  ('Japan', Decimal('364500.00'), 'Eastern Asia', Decimal('3.212385')),
#  ('Jordan', Decimal('88794.00'), 'Western Asia', Decimal('2.545264')),
#  ('Kazakhstan', Decimal('2699700.00'), 'Central Asia', Decimal('72.009858')),
#  ('Kenya', Decimal('569140.00'), 'Eastern Africa', Decimal('9.566711')),
#  ('Kiribati', Decimal('810.00'), 'Micronesia', Decimal('32.793522')),
#  ('Kuwait', Decimal('17820.00'), 'Western Asia', Decimal('0.510807')),
#  ('Kyrgyzstan', None, 'Central Asia', None),
#  ("Lao People's Democratic Republic", None, 'South-Eastern Asia', None),
#  ('Lebanon', Decimal('10230.00'), 'Western Asia', Decimal('0.293241')),
#  ('Lesotho', Decimal('30360.00'), 'Southern Africa', Decimal('1.145371')),
#  ('Liberia', Decimal('96320.00'), 'Western Africa', Decimal('1.679351')),
#  ('Libya', Decimal('1759540.00'), 'Northern Africa', Decimal('26.615576')),
#  ('Madagascar', Decimal('581800.00'), 'Eastern Africa', Decimal('9.779514')),
#  ('Malawi', Decimal('94280.00'), 'Eastern Africa', Decimal('1.584759')),
#  ('Malaysia', Decimal('328550.00'), 'South-Eastern Asia', Decimal('8.499356')),
#  ('Maldives', Decimal('300.00'), 'Southern Asia', Decimal('0.006289')),
#  ('Mali', Decimal('1220190.00'), 'Western Africa', Decimal('21.274159')),
#  ('Marshall Islands', Decimal('180.00'), 'Micronesia', Decimal('7.287449')),
#  ('Martinique', None, 'Caribbean', None),
#  ('Mauritania', Decimal('1030700.00'), 'Western Africa', Decimal('17.970378')),
#  ('Mauritius', Decimal('2030.00'), 'Eastern Africa', Decimal('0.034122')),
#  ('Mayotte', None, 'Eastern Africa', None),
#  ('Mexico', Decimal('1943950.00'), 'Central America', Decimal('79.276623')),
#  ('Micronesia (Federated States of)', None, 'Micronesia', None),
#  ('Mongolia', Decimal('1557506.80'), 'Eastern Asia', Decimal('13.726506')),
#  ('Montserrat', None, 'Caribbean', None),
#  ('Morocco', Decimal('446300.00'), 'Northern Africa', Decimal('6.750930')),
#  ('Mozambique', Decimal('786380.00'), 'Eastern Africa', Decimal('13.218312')),
#  ('Myanmar', Decimal('653080.00'), 'South-Eastern Asia', Decimal('16.894717')),
#  ('Namibia', Decimal('823290.00'), 'Southern Africa', Decimal('31.059694')),
#  ('Nauru', Decimal('20.00'), 'Micronesia', Decimal('0.809717')),
#  ('Nepal', Decimal('143350.00'), 'Southern Asia', Decimal('3.005142')),
#  ('New Caledonia', Decimal('18280.00'), 'Melanesia', Decimal('3.451727')),
#  ('New Zealand', Decimal('263310.00'), 'Australia and New Zealand', Decimal('3.309856')),
#  ('Nicaragua', Decimal('120340.00'), 'Central America', Decimal('4.907610')),
#  ('Niger', Decimal('1266700.00'), 'Western Africa', Decimal('22.085066')),
#  ('Nigeria', Decimal('910770.00'), 'Western Africa', Decimal('15.879384')),
#  ('Niue', None, 'Polynesia', None),
#  ('Northern Mariana Islands', Decimal('460.00'), 'Micronesia', Decimal('18.623482')),
#  ('Oman', Decimal('309500.00'), 'Western Asia', Decimal('8.871761')),
#  ('Pakistan', Decimal('770880.00'), 'Southern Asia', Decimal('16.160474')),
#  ('Palau', Decimal('460.00'), 'Micronesia', Decimal('18.623482')),
#  ('Panama', Decimal('74180.00'), 'Central America', Decimal('3.025150')),
#  ('Papua New Guinea', Decimal('452860.00'), 'Melanesia', Decimal('85.511433')),
#  ('Paraguay', Decimal('397300.00'), 'South America', Decimal('2.579637')),
#  ('Peru', Decimal('1280000.00'), 'South America', Decimal('8.310937')),
#  ('Philippines', Decimal('298170.00'), 'South-Eastern Asia', Decimal('7.713447')),
#  ('Puerto Rico', Decimal('8870.00'), 'Caribbean', Decimal('4.257995')),
#  ('Qatar', Decimal('11490.00'), 'Western Asia', Decimal('0.329359')),
#  ('Republic of Korea', None, 'Eastern Asia', None),
#  ('Réunion', None, 'Eastern Africa', None),
#  ('Rwanda', Decimal('24670.00'), 'Eastern Africa', Decimal('0.414680')),
#  ('Saint Barthélemy', None, 'Caribbean', None),
#  ('Saint Helena', None, 'Western Africa', None),
#  ('Saint Kitts and Nevis', None, 'Caribbean', None),
#  ('Saint Lucia', None, 'Caribbean', None),
#  ('Saint Martin (French Part)', None, 'Caribbean', None),
#  ('Saint Pierre and Miquelon', None, 'Northern America', None),
#  ('Saint Vincent and the Grenadines', None, 'Caribbean', None),
#  ('Samoa', Decimal('2830.00'), 'Polynesia', Decimal('39.029099')),
#  ('Sao Tome and Principe', Decimal('960.00'), 'Middle Africa', Decimal('0.024690')),
#  ('Saudi Arabia', Decimal('2149690.00'), 'Western Asia', Decimal('61.620474')),
#  ('Senegal', Decimal('192530.00'), 'Western Africa', Decimal('3.356784')),
#  ('Seychelles', Decimal('460.00'), 'Eastern Africa', Decimal('0.007732')),
#  ('Sierra Leone', Decimal('72180.00'), 'Western Africa', Decimal('1.258467')),
#  ('Singapore', Decimal('718.00'), 'South-Eastern Asia', Decimal('0.018574')),
#  ('Sint Maarten (Dutch part)', Decimal('34.00'), 'Caribbean', Decimal('0.016322')),
#  ('Solomon Islands', Decimal('27990.00'), 'Melanesia', Decimal('5.285221')),
#  ('Somalia', Decimal('627340.00'), 'Eastern Africa', Decimal('10.544999')),
#  ('South Africa', Decimal('1213090.00'), 'Southern Africa', Decimal('45.765410')),
#  ('South Sudan', Decimal('631930.00'), 'Eastern Africa', Decimal('10.622152')),
#  ('Sri Lanka', Decimal('61893.00'), 'Southern Asia', Decimal('1.297504')),
#  ('State of Palestine', None, 'Western Asia', None),
#  ('Sudan', Decimal('1868000.00'), 'Northern Africa', Decimal('28.256189')),
#  ('Suriname', Decimal('156000.00'), 'South America', Decimal('1.012895')),
#  ('Syrian Arab Republic', Decimal('183630.00'), 'Western Asia', Decimal('5.263721')),
#  ('Tajikistan', Decimal('138790.00'), 'Central Asia', Decimal('3.701985')),
#  ('Thailand', Decimal('510890.00'), 'South-Eastern Asia', Decimal('13.216363')),
#  ('Timor-Leste', Decimal('14870.00'), 'South-Eastern Asia', Decimal('0.384676')),
#  ('Togo', Decimal('54390.00'), 'Western Africa', Decimal('0.948296')),
#  ('Tokelau', None, 'Polynesia', None),
#  ('Tonga', Decimal('720.00'), 'Polynesia', Decimal('9.929665')),
#  ('Trinidad and Tobago', Decimal('5130.00'), 'Caribbean', Decimal('2.462629')),
#  ('Tunisia', Decimal('155360.00'), 'Northern Africa', Decimal('2.350044')),
#  ('Türkiye', None, 'Western Asia', None),
#  ('Turkmenistan', Decimal('469930.00'), 'Central Asia', Decimal('12.534575')),
#  ('Turks and Caicos Islands', Decimal('950.00'), 'Caribbean', Decimal('0.456042')),
#  ('Tuvalu', Decimal('30.00'), 'Polynesia', Decimal('0.413736')),
#  ('Uganda', Decimal('200520.00'), 'Eastern Africa', Decimal('3.370554')),
#  ('United Arab Emirates', Decimal('71020.00'), 'Western Asia', Decimal('2.035775')),
#  ('United Republic of Tanzania', None, 'Eastern Africa', None),
#  ('United States of America', None, 'Northern America', None),
#  ('United States Virgin Islands', None, 'Caribbean', None),
#  ('Uruguay', Decimal('175020.00'), 'South America', Decimal('1.136391')),
#  ('Uzbekistan', Decimal('440650.00'), 'Central Asia', Decimal('11.753582')),
#  ('Vanuatu', Decimal('12190.00'), 'Melanesia', Decimal('2.301781')),
#  ('Venezuela (Bolivarian Republic of)', None, 'South America', None),
#  ('Viet Nam', None, 'South-Eastern Asia', None),
#  ('Wallis and Futuna Islands', None, 'Polynesia', None),
#  ('Yemen', None, 'Western Asia', None),
#  ('Zambia', Decimal('743390.00'), 'Eastern Africa', Decimal('12.495691')),
#  ('Zimbabwe', Decimal('386850.00'), 'Eastern Africa', Decimal('6.502587'))]

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     serv.Pct_access_to_basic_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS serv
#     ON econ.Country_name = serv.Country_name AND econ.Time_period = serv.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# (pymysql.err.OperationalError) (1054, "Unknown column 'serv.Pct_access_to_basic_services' in 'field list'")
# [SQL: SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     serv.Pct_access_to_basic_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS serv
#     ON econ.Country_name = serv.Country_name AND econ.Time_period = serv.Time_period
# LIMIT 10;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
# 1 rows affected.
# [(None,)]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///dam_levels-a-3987.db

# %%
# %%sql sqlite:///dam_levels-a-3987.db
#
# SELECT * FROM dam_levels
# Out:
# Done.
# [('2012', 'WEMMERSHOEK', 'P. M. Naidoo', '201013', '48.2', '-33.826246', '19.091828'),
#  ('2012', 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', '201124', '20.3;24.2', '-34.180527;-34.166702', '18.866688;18.90976'),
#  ('2012', 'VOËLVLEI', 'A. T. Sijovu', '202256', '15', '-33.34178', '19.04105'),
#  ('2012', 'HELY-HUTCHINSON', 'P. M. Naidoo', '201013', '14.2', '-33.976929', '18.409568'),
#  ('2012', 'WOODHEAD', 'A. T. Sijovu', '202256', '35.3', '-33.977341', '18.404046'),
#  ('2013', 'WEMMERSHOEK', 'P. M. Naidoo', '201013', '53.3', '-33.826246', '19.091828'),
#  ('2013', 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', '201124', '22.4;24.6', '-34.180527;-34.166702', '18.866688;18.90976'),
#  ('2013', 'VOËLVLEI', 'A. T. Sijovu', '202256', '16.6', '-33.34178', '19.04105'),
#  ('2013', 'HELY-HUTCHINSON', 'P. M. Naidoo', '201013', '15.2', '-33.976929', '18.409568'),
#  ('2013', 'WOODHEAD', 'A. T. Sijovu', '202256', '35.9', '-33.977341', '18.404046'),
#  ('2015', 'WEMMERSHOEK', 'P. M. Naidoo', '201013', '47.5', '-33.826246', '19.091828'),
#  ('2015', 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', '201124', '22.7;24.6', '-34.180527;-34.166702', '18.866688;18.90976'),
#  ('2015', 'VOËLVLEI', 'A. T. Sijovu', '202256', '11.9', '-33.34178', '19.04105'),
#  ('2015', 'HELY-HUTCHINSON', 'P. M. Naidoo', '201013', '15.3', '-33.976929', '18.409568'),
#  ('2015', 'WOODHEAD', 'A. T. Sijovu', '202256', '36.1', '-33.977341', '18.404046')]

# %%
# %%sql
#
# DELETE
# FROM
#     dam_levels
# WHERE
#     Assessment_Officer = "V. Mokere";
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# 3 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO dam_levels (year,dam_name,Assessment_Officer,Officer_Reg,water_level,dam_latitude,dam_longitude)
# VALUES
#     ( 2012,"STEENBRAS LOWER","V. Mokere",201124,20.3,-34.180527,18.866688),
#     ( 2012,"STEENBRAS UPPER","V. Mokere",201124,24.2,-34.166702,18.90976),
#     ( 2013,"STEENBRAS LOWER","V. Mokere",201124,22.4,-34.180527,18.866688),
#     ( 2013,"STEENBRAS UPPER","V. Mokere",201124,24.6,-34.166702,18.90976),
#     ( 2015,"STEENBRAS LOWER","V. Mokere",201124,22.7,-34.180527,18.866688),
#     ( 2015,"STEENBRAS UPPER","V. Mokere",201124,24.6,-34.16670,18.90976);
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# 6 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE dam_levels_1nf (
#     AssessmentId INTEGER PRIMARY KEY AUTOINCREMENT,
#     year INTEGER,
#     dam_name VARCHAR(100),
#     Assessment_Officer VARCHAR(100),
#     Officer_Reg INTEGER,
#     water_level NUMERIC(10,1),
#     dam_latitude NUMERIC(3,6),
#     dam_longitude NUMERIC(3,6)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# INSERT INTO
#     dam_levels_1nf(
#             year,
#             dam_name,
#             Assessment_Officer,
#             Officer_Reg,
#             water_level,
#             dam_latitude,
#             dam_longitude
#         )
# SELECT
#     year,
#     dam_name,
#     Assessment_Officer,
#     Officer_Reg,
#     water_level,
#     dam_latitude,
#     dam_longitude
# FROM
#     dam_levels
# ORDER BY year;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# 18 rows affected.
# []

# %%
# %%sql
#
# DROP TABLE dam_levels;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# SELECT *
# FROM dam_levels_1nf
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# [(1, 2012, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 48.2, -33.826246, 19.091828),
#  (2, 2012, 'VOËLVLEI', 'A. T. Sijovu', 202256, 15, -33.34178, 19.04105),
#  (3, 2012, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 14.2, -33.976929, 18.409568),
#  (4, 2012, 'WOODHEAD', 'A. T. Sijovu', 202256, 35.3, -33.977341, 18.404046),
#  (5, 2012, 'STEENBRAS LOWER', 'V. Mokere', 201124, 20.3, -34.180527, 18.866688),
#  (6, 2012, 'STEENBRAS UPPER', 'V. Mokere', 201124, 24.2, -34.166702, 18.90976),
#  (7, 2013, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 53.3, -33.826246, 19.091828),
#  (8, 2013, 'VOËLVLEI', 'A. T. Sijovu', 202256, 16.6, -33.34178, 19.04105),
#  (9, 2013, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 15.2, -33.976929, 18.409568),
#  (10, 2013, 'WOODHEAD', 'A. T. Sijovu', 202256, 35.9, -33.977341, 18.404046),
#  (11, 2013, 'STEENBRAS LOWER', 'V. Mokere', 201124, 22.4, -34.180527, 18.866688),
#  (12, 2013, 'STEENBRAS UPPER', 'V. Mokere', 201124, 24.6, -34.166702, 18.90976),
#  (13, 2015, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 47.5, -33.826246, 19.091828),
#  (14, 2015, 'VOËLVLEI', 'A. T. Sijovu', 202256, 11.9, -33.34178, 19.04105),
#  (15, 2015, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 15.3, -33.976929, 18.409568),
#  (16, 2015, 'WOODHEAD', 'A. T. Sijovu', 202256, 36.1, -33.977341, 18.404046),
#  (17, 2015, 'STEENBRAS LOWER', 'V. Mokere', 201124, 22.7, -34.180527, 18.866688),
#  (18, 2015, 'STEENBRAS UPPER', 'V. Mokere', 201124, 24.6, -34.1667, 18.90976)]

# %%
# %%sql
#
# CREATE TABLE assessments (
#     AssessmentId INTEGER PRIMARY KEY AUTOINCREMENT,
#     year INTEGER,
#     Assessment_Officer VARCHAR(100),
#     Officer_Reg INTEGER,
#     water_level NUMERIC(10,1)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE dams (
#     dam_name VARCHAR(100),
#     dam_latitude NUMERIC(3,6),
#     dam_longitude NUMERIC(3,6)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     assessments
# LIMIT 10; -- Remove this line to see the full query output
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE water_level_assessments (
#     AssessmentId INTEGER PRIMARY KEY AUTOINCREMENT,
#     year INTEGER,
#     Officer_Reg INTEGER,
#     water_level NUMERIC(10,1)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///chinook.db
#  * sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# []

# %%
# %%sql
#
# DROP table assessments;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# (sqlite3.OperationalError) no such table: assessments
# [SQL: DROP table assessments;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SoftDevEmployees.db

# %%
# %%sql
# SELECT *
# FROM
#     employees
# WHERE
#     Role LIKE '%,%'    -- we use the LIKE keyword to search for the comma "," delimiter
# OR
#     Department LIKE '%,%' -- we use the LIKE keyword to search for the comma "," delimiter
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# [('Dumisani,     Thwala', 'Mr', 'Back-End Developer', 'Graduate', 52171, 'Web Applications, Mobile Applications'),
#  ('Dirk,Banda', 'Mr', 'Business Analyst', 'Intern', 37601, 'Web Applications,Mobile Applications'),
#  ('barend,Edwards', 'MR', 'Database Analyst', 'Intern', 13163, 'Web Applications, Mobile Applications'),
#  ('kelly            ,Manuel', 'Ms', 'Full-Stack Developer', 'Intern', 47442, 'Web Applications, Mobile Applications'),
#  ('Janet,Patel', 'Ms', 'Systems Analyst', 'Intern', 39081, 'Web Applications, Mobile Applications'),
#  ('Christopher,     Walker', 'Mr', 'Back-End Developer', 'Junior', 122894, 'Web Applications, Mobile Applications'),
#  ('Marco              ,    Morris', 'prof', 'Back-End Developer', 'Mid-Level', 110506, 'Web Applications, Mobile Applications'),
#  ('Danie   ,Campbell', 'Mrs', 'Business Analyst', 'Mid-Level', 205621, 'Web Applications, Mobile Applications'),
#  ('Jessica          ,Mchunu', 'miss', 'Full-Stack Developer, Scrum Master', 'Mid-Level', 70741, 'Web Applications'),
#  ('Laura,Makhanya', 'Ms', 'Full-Stack Developer, Team Lead', 'Senior', 293352, 'Mobile Applications'),
#  ('Nico,Mthembu', 'Mr', 'Systems Analyst, Project Manager', 'Senior', 97673, 'Mobile Applications')]

# %%
# %%sql
#
# DROP TABLE IF EXISTS Employees_1NF; -- We delete the table in case it exits when we create it.
#
# CREATE TABLE Employees_1NF (
#     Name VARCHAR NOT NULL,
#     Surname VARCHAR NOT NULL,
#     Role VARCHAR NOT NULL,
#     Department VARCHAR NOT NULL,
#     Title VARCHAR,
#     OccupationBand VARCHAR,
#     Salary REAL,
#     PRIMARY KEY(Name, Surname, Role, Department)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT
#     FullName,
#     TRIM(SUBSTR(FullName,1,INSTR(FullName,',')-1)) AS Name, --Get substring before comma
#     TRIM(SUBSTR(FullName,INSTR(FullName,',')+1)) AS Surname, --Get substring after comma
#     UPPER(SUBSTR(Title,1,1)) ||LOWER(SUBSTR(Title,2)) AS Title --Standardising all Titles to start with a capital letter
# FROM
#     Employees
# LIMIT 5;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
# Done.
# [('Dumisani,     Thwala', 'Dumisani', 'Thwala', 'Mr'),
#  ('Tony,   Horn', 'Tony', 'Horn', 'Mr'),
#  ('Vuyokazi,barnes', 'Vuyokazi', 'barnes', 'Mr'),
#  ('sello  ,Details', 'sello', 'Details', 'Mr'),
#  ('Jacqueline       ,fredericks', 'Jacqueline', 'fredericks', 'Ms')]

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///flights.db

# %%
# %%time
# %%sql

SELECT TailNum, DepDelay
FROM flights
LIMIT 50
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 0 ns
# Wall time: 231 ms
# [('N712SW', 8.0),
#  ('N772SW', 19.0),
#  ('N428WN', 8.0),
#  ('N612SW', -4.0),
#  ('N464WN', 34.0),
#  ('N726SW', 25.0),
#  ('N763SW', 67.0),
#  ('N428WN', -1.0),
#  ('N689SW', 2.0),
#  ('N648SW', 0.0),
#  ('N690SW', 6.0),
#  ('N334SW', 94.0),
#  ('N476WN', -4.0),
#  ('N765SW', 0.0),
#  ('N420WN', 2.0),
#  ('N263WN', 9.0),
#  ('N286WN', 27.0),
#  ('N778SW', 9.0),
#  ('N674AA', 28.0),
#  ('N643SW', 51.0),
#  ('N497WN', 1.0),
#  ('N724SW', 32.0),
#  ('N786SW', 20.0),
#  ('N714CB', 9.0),
#  ('N222WN', 1.0),
#  ('N394SW', 25.0),
#  ('N215WN', 87.0),
#  ('N243WN', 29.0),
#  ('N454WN', 1.0),
#  ('N712SW', 4.0),
#  ('N798SW', 82.0),
#  ('N736SA', 3.0),
#  ('N795SW', 2.0),
#  ('N247WN', 12.0),
#  ('N707SA', 19.0),
#  ('N443WN', 39.0),
#  ('N753SW', 1.0),
#  ('N779SW', 82.0),
#  ('N704SW', 22.0),
#  ('N709SW', 29.0),
#  ('N459WN', 56.0),
#  ('N621SW', 24.0),
#  ('N206WN', 6.0),
#  ('N280WN', 6.0),
#  ('N241WN', 13.0),
#  ('N200WN', 18.0),
#  ('N459WN', -1.0),
#  ('N286WN', 1.0),
#  ('N475WN', 15.0),
#  ('N792SW', 315.0)]

# %%
# %%time
# %%sql

SELECT TailNum, DepDelay
FROM flights
LIMIT 50
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 15.6 ms
# Wall time: 8.28 ms
# [('N712SW', 8.0),
#  ('N772SW', 19.0),
#  ('N428WN', 8.0),
#  ('N612SW', -4.0),
#  ('N464WN', 34.0),
#  ('N726SW', 25.0),
#  ('N763SW', 67.0),
#  ('N428WN', -1.0),
#  ('N689SW', 2.0),
#  ('N648SW', 0.0),
#  ('N690SW', 6.0),
#  ('N334SW', 94.0),
#  ('N476WN', -4.0),
#  ('N765SW', 0.0),
#  ('N420WN', 2.0),
#  ('N263WN', 9.0),
#  ('N286WN', 27.0),
#  ('N778SW', 9.0),
#  ('N674AA', 28.0),
#  ('N643SW', 51.0),
#  ('N497WN', 1.0),
#  ('N724SW', 32.0),
#  ('N786SW', 20.0),
#  ('N714CB', 9.0),
#  ('N222WN', 1.0),
#  ('N394SW', 25.0),
#  ('N215WN', 87.0),
#  ('N243WN', 29.0),
#  ('N454WN', 1.0),
#  ('N712SW', 4.0),
#  ('N798SW', 82.0),
#  ('N736SA', 3.0),
#  ('N795SW', 2.0),
#  ('N247WN', 12.0),
#  ('N707SA', 19.0),
#  ('N443WN', 39.0),
#  ('N753SW', 1.0),
#  ('N779SW', 82.0),
#  ('N704SW', 22.0),
#  ('N709SW', 29.0),
#  ('N459WN', 56.0),
#  ('N621SW', 24.0),
#  ('N206WN', 6.0),
#  ('N280WN', 6.0),
#  ('N241WN', 13.0),
#  ('N200WN', 18.0),
#  ('N459WN', -1.0),
#  ('N286WN', 1.0),
#  ('N475WN', 15.0),
#  ('N792SW', 315.0)]

# %%
# %%time
# %%sql

SELECT FlightNum, TailNum, Description
FROM flights
INNER JOIN carriers
ON carriers.Code = flights.UniqueCarrier
LIMIT 2500;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 46.9 ms
# Wall time: 197 ms

# %%
# %%time
# %%sql

SELECT TailNum, Distance
FROM flights
WHERE TailNum LIKE 'N7%'
LIMIT 2500;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 78.1 ms
# Wall time: 224 ms

# %%
# %%time
# %%sql

SELECT TailNum, DepDelay
FROM flights
WHERE AirTime/5 < DepDelay
LIMIT 5000;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 31.2 ms
# Wall time: 39.1 ms

# %%
# %%time
# %%sql

SELECT TailNum, DepDelay
FROM flights
WHERE AirTime/5 < DepDelay
LIMIT 5000;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#    sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#  * sqlite:///flights.db
# Done.
# CPU times: total: 0 ns
# Wall time: 43.6 ms

# %%
# %sql sqlite:///SoftDevEmployees.db

# %%
# %%sql
#
# DROP TABLE IF EXISTS Departments_3NF;
# DROP TABLE IF EXISTS Employee_Department_3NF;
# DROP TABLE IF EXISTS Employee_Role_3NF;
# DROP TABLE IF EXISTS Roles_3NF;
# DROP TABLE IF EXISTS Titles_3NF;
#
# CREATE TABLE Departments_3NF AS
# SELECT * FROM Departments_2NF;
#
# CREATE TABLE Employee_Department_3NF AS
# SELECT * FROM Employee_Department_2NF;
#
# CREATE TABLE Employee_Role_3NF AS
# SELECT * FROM Employee_Role_2NF;
#
# CREATE TABLE Roles_3NF AS
# SELECT * FROM Roles_2NF;
#
# CREATE TABLE Titles_3NF AS
# SELECT * FROM Titles_2NF;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#    sqlite:///flights.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS Salaries_3NF;
# DROP TABLE IF EXISTS OccupationBands_3NF;
#
# CREATE TABLE Salaries_3NF(
#     SalaryID INTEGER NOT NULL,
#     Salary REAL,
#     BandID INTEGER,
#     FOREIGN KEY(BandID) REFERENCES OccupationBands (BandID),
#     PRIMARY KEY(SalaryID AUTOINCREMENT)
# );
#
# CREATE TABLE OccupationBands_3NF (
#     BandID INTEGER NOT NULL,
#     OccupationBand VARCHAR,
#     PRIMARY KEY(BandID AUTOINCREMENT)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#    sqlite:///flights.db
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# DELETE FROM OccupationBands_3NF;
# DELETE FROM Salaries_3NF;
#
# INSERT INTO OccupationBands_3NF (OccupationBand)
# SELECT DISTINCT
#     OccupationBand
# FROM Employees_2NF;
#
# INSERT INTO Salaries_3NF (Salary,BandID)
# SELECT
#     Salary,
#     OB.BandID
# FROM Employees_2NF AS EMP
# JOIN OccupationBands_3NF AS OB ON OB.OccupationBand = EMP.OccupationBand;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#    sqlite:///flights.db
# 0 rows affected.
# 0 rows affected.
# 5 rows affected.
# 49 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS Employees_3NF;
#
# CREATE TABLE Employees_3NF (
#     EmployeeID INTEGER NOT NULL,
#     Name VARCHAR,
#     Surname VARCHAR,
#     TitleID INTEGER,
#     SalaryID INTEGER,
#     FOREIGN KEY(TitleID) REFERENCES Titles_3NF (TitleID)
#     FOREIGN KEY(SalaryID) REFERENCES Salaries_3NF (SalaryID)
#     PRIMARY KEY(EmployeeID AUTOINCREMENT)
# );
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#    sqlite:///flights.db
# Done.
# Done.
# []

# %%
# %%sql
#
# DELETE FROM Employees_3NF;
#
# INSERT INTO Employees_3NF (Name,Surname,TitleID,SalaryID)
# SELECT
#     Name,
#     Surname,
#     TitleID,
#     SalaryID
# FROM Employees_2NF AS EMP
# JOIN Salaries_3NF AS S ON EMP.Salary = S.Salary;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#    sqlite:///Northwind.db
#  * sqlite:///SoftDevEmployees.db
#    sqlite:///chinook.db
#    sqlite:///dam_levels-a-3987.db
#    sqlite:///dam_levels.db
#    sqlite:///flights.db
# 0 rows affected.
# 49 rows affected.
# []
